# %% [markdown]
# # WeatherPy
#
# ### Analysis
# -  Looking at the City Latitude vs Temperature scatterplot, it is made evident that the closer a city is to the equator (x-value = 0), the higher the temperature of the city is.
# -  In City Latitude vs Humidity scatterplot, we see that there is no true correlation between a city's humidity and its latitude. Visualization shows that there are cities ranging from latitude -50 to latitude 70 that all have 100% humidity.
# -  Cloudiness % also does not appear to have a correlation to a city's latitude. However, a large population of the data had 0% cloudiness. Those cities may tend to be higher in temperature since there is no cloud coverage. Just a theory however.... would need further analysis to be determined.
#     -  Further analysis determined that the above theory is only true between latitudes 60 to 80 (Refer to final Figure).
# -  The majority of the randomly selected cities had a wind speed in the range of 0-10 mph. However, cities equal distance from the equator (latitudes -20 to -40; latitudes 20 to 40), on average, had a higher wind speed, reaching top speeds of over 35 mph.

# %%
#Install citipy library
# !pip install citipy

#Dependencies
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import requests
import time

from citipy import citipy
from pprint import pprint

#Import API key for OpenWeatherMapy
from config import owm_key
# Out:
# Requirement already satisfied: citipy in c:\users\austi\anaconda3\envs\pythondata\lib\site-packages
# Requirement already satisfied: kdtree>=0.12 in c:\users\austi\anaconda3\envs\pythondata\lib\site-packages (from citipy)
# You are using pip version 9.0.1, however version 9.0.3 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %% [markdown]
# ### Generate Cities List

# %%
#Create DataFrame
cities_df = pd.DataFrame()

#Add columns for City and Country
cities_df["City"] = ""
cities_df["Country"] = ""

#Generate 500+ random latitudes and longitudes, then add new columns and values to Dataframe
cities_df["Latitude"] = np.random.uniform(low=-90, high=90, size=1500)
cities_df["Longitude"] = np.random.uniform(low=-180, high=180, size=1500)
cities_df = round(cities_df, 2)

#Add columns to DataFrame for wanted values
cities_df["Temperature (F)"] = ""
cities_df["Humidity (%)"] = ""
cities_df["Cloudiness (%)"] = ""
cities_df["Wind Speed (mph)"] = ""

#Find and add nearest city & country based on the randomly selected lat and lng
for index, row in cities_df.iterrows():
    lat = row["Latitude"]
    lng = row["Longitude"]
    cities_df.set_value(index, "City", citipy.nearest_city(lat, lng).city_name)
    cities_df.set_value(index, "Country", citipy.nearest_city(lat, lng).country_code)

#Drop duplicate cities
cities_df.drop_duplicates(["City", "Country"], inplace=True)
cities_df.reset_index(inplace=True)

#Delete unneccesary column for aesthetics 
del cities_df["index"]

#Display updated DataFrame
cities_df.head()
# Out:
# C:\Users\austi\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:23: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Users\austi\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:24: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#             City Country  Latitude  Longitude Temperature (F) Humidity (%)  \
# 0      maniitsoq      gl     66.47     -50.79
# 1        ushuaia      ar    -64.33     -59.44
# 2  san cristobal      ec     -9.74     -88.73
# 3          tiksi      ru     72.64     127.00
# 4    fort nelson      ca     62.72    -121.63
#
#   Cloudiness (%) Wind Speed (mph)
# 0
# 1
# 2
# 3
# 4

# %%
#Check to be sure we have 500+ cities for dataset
len(cities_df)
# Out:
# 641

# %% [markdown]
# ### Perform API Calls

# %%
#Config info
units = "imperial"

#Access the data from openweathermapy
print("Beginning Data Retrieval")
print("---------------------------------------------------------------")

for index, row in cities_df.iterrows():
    #Target URL
    query_url = "http://api.openweathermap.org/data/2.5/weather?q=%s,%s&units=%s&appid=%s" % (row["City"], row["Country"], units, owm_key)
    
    #Print log of cities being processed
    print(f"Now retrieving City #" + str(index) + ": " + row["City"] + ", " + row["Country"])
    print(query_url)
    
    #Run requests to API
    weather_data = requests.get(query_url).json()
    
    #Use exceptional handling  to calculate and append values to DataFrame
    try:
        response = weather_data
        cities_df.set_value(index, "Temperature (F)", response["main"]["temp"])
        cities_df.set_value(index, "Humidity (%)", response["main"]["humidity"])
        cities_df.set_value(index, "Cloudiness (%)", response["clouds"]["all"])
        cities_df.set_value(index, "Wind Speed (mph)", response["wind"]["speed"])
    except:
        print("Error with city data... Skipping")
    
    
print("---------------------------------------------------------------")
print("Data Retrieval Complete")
print("---------------------------------------------------------------")  

#Covert strings to floats for DataFrame
columns = ["Latitude", "Longitude", "Temperature (F)", "Humidity (%)", "Cloudiness (%)", "Wind Speed (mph)"]
for column in columns:
    cities_df[column] = pd.to_numeric(cities_df[column], errors="coerce")
# Out:
# Beginning Data Retrieval
# ---------------------------------------------------------------
# Now retrieving City #0: maniitsoq, gl
# http://api.openweathermap.org/data/2.5/weather?q=maniitsoq,gl&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# C:\Users\austi\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:22: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Users\austi\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:23: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Users\austi\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:24: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Users\austi\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:25: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# Now retrieving City #1: ushuaia, ar
# http://api.openweathermap.org/data/2.5/weather?q=ushuaia,ar&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #2: san cristobal, ec
# http://api.openweathermap.org/data/2.5/weather?q=san cristobal,ec&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #3: tiksi, ru
# http://api.openweathermap.org/data/2.5/weather?q=tiksi,ru&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #4: fort nelson, ca
# http://api.openweathermap.org/data/2.5/weather?q=fort nelson,ca&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #5: van, tr
# http://api.openweathermap.org/data/2.5/weather?q=van,tr&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #6: port alfred, za
# http://api.openweathermap.org/data/2.5/weather?q=port alfred,za&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #7: kapaa, us
# http://api.openweathermap.org/data/2.5/weather?q=kapaa,us&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #8: shushtar, ir
# http://api.openweathermap.org/data/2.5/weather?q=shushtar,ir&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #9: esso, ru
# http://api.openweathermap.org/data/2.5/weather?q=esso,ru&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #10: rikitea, pf
# http://api.openweathermap.org/data/2.5/weather?q=rikitea,pf&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #11: coquimbo, cl
# http://api.openweathermap.org/data/2.5/weather?q=coquimbo,cl&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #12: druskininkai, lt
# http://api.openweathermap.org/data/2.5/weather?q=druskininkai,lt&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #13: flinders, au
# http://api.openweathermap.org/data/2.5/weather?q=flinders,au&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #14: victoria, sc
# http://api.openweathermap.org/data/2.5/weather?q=victoria,sc&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #15: sangar, ru
# http://api.openweathermap.org/data/2.5/weather?q=sangar,ru&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #16: barrow, us
# http://api.openweathermap.org/data/2.5/weather?q=barrow,us&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #17: sola, vu
# http://api.openweathermap.org/data/2.5/weather?q=sola,vu&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #18: nuuk, gl
# http://api.openweathermap.org/data/2.5/weather?q=nuuk,gl&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #19: husavik, is
# http://api.openweathermap.org/data/2.5/weather?q=husavik,is&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #20: mahebourg, mu
# http://api.openweathermap.org/data/2.5/weather?q=mahebourg,mu&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #21: andrelandia, br
# http://api.openweathermap.org/data/2.5/weather?q=andrelandia,br&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Error with city data... Skipping
# Now retrieving City #22: guerrero negro, mx
# http://api.openweathermap.org/data/2.5/weather?q=guerrero negro,mx&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #23: busselton, au
# http://api.openweathermap.org/data/2.5/weather?q=busselton,au&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #24: bredasdorp, za
# http://api.openweathermap.org/data/2.5/weather?q=bredasdorp,za&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #25: butaritari, ki
# http://api.openweathermap.org/data/2.5/weather?q=butaritari,ki&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #26: albany, au
# http://api.openweathermap.org/data/2.5/weather?q=albany,au&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #27: yellowknife, ca
# http://api.openweathermap.org/data/2.5/weather?q=yellowknife,ca&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #28: buala, sb
# http://api.openweathermap.org/data/2.5/weather?q=buala,sb&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #29: naze, jp
# http://api.openweathermap.org/data/2.5/weather?q=naze,jp&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #30: san carlos de bariloche, ar
# http://api.openweathermap.org/data/2.5/weather?q=san carlos de bariloche,ar&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #31: sitka, us
# http://api.openweathermap.org/data/2.5/weather?q=sitka,us&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #32: bilma, ne
# http://api.openweathermap.org/data/2.5/weather?q=bilma,ne&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #33: upernavik, gl
# http://api.openweathermap.org/data/2.5/weather?q=upernavik,gl&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #34: akyab, mm
# http://api.openweathermap.org/data/2.5/weather?q=akyab,mm&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Error with city data... Skipping
# Now retrieving City #35: qaqortoq, gl
# http://api.openweathermap.org/data/2.5/weather?q=qaqortoq,gl&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #36: airai, pw
# http://api.openweathermap.org/data/2.5/weather?q=airai,pw&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Error with city data... Skipping
# Now retrieving City #37: san policarpo, ph
# http://api.openweathermap.org/data/2.5/weather?q=san policarpo,ph&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #38: assiniboia, ca
# http://api.openweathermap.org/data/2.5/weather?q=assiniboia,ca&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #39: nikolskoye, ru
# http://api.openweathermap.org/data/2.5/weather?q=nikolskoye,ru&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #40: sao joao da barra, br
# http://api.openweathermap.org/data/2.5/weather?q=sao joao da barra,br&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #41: hobart, au
# http://api.openweathermap.org/data/2.5/weather?q=hobart,au&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #42: baykit, ru
# http://api.openweathermap.org/data/2.5/weather?q=baykit,ru&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #43: khandyga, ru
# http://api.openweathermap.org/data/2.5/weather?q=khandyga,ru&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #44: sfantu gheorghe, ro
# http://api.openweathermap.org/data/2.5/weather?q=sfantu gheorghe,ro&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #45: casablanca, ma
# http://api.openweathermap.org/data/2.5/weather?q=casablanca,ma&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #46: shimoda, jp
# http://api.openweathermap.org/data/2.5/weather?q=shimoda,jp&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #47: yangshan, cn
# http://api.openweathermap.org/data/2.5/weather?q=yangshan,cn&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #48: vieste, it
# http://api.openweathermap.org/data/2.5/weather?q=vieste,it&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #49: port elizabeth, za
# http://api.openweathermap.org/data/2.5/weather?q=port elizabeth,za&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #50: naryan-mar, ru
# http://api.openweathermap.org/data/2.5/weather?q=naryan-mar,ru&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #51: yeppoon, au
# http://api.openweathermap.org/data/2.5/weather?q=yeppoon,au&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #52: marsh harbour, bs
# http://api.openweathermap.org/data/2.5/weather?q=marsh harbour,bs&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #53: saint-philippe, re
# http://api.openweathermap.org/data/2.5/weather?q=saint-philippe,re&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #54: new norfolk, au
# http://api.openweathermap.org/data/2.5/weather?q=new norfolk,au&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #55: excelsior springs, us
# http://api.openweathermap.org/data/2.5/weather?q=excelsior springs,us&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #56: ketchikan, us
# http://api.openweathermap.org/data/2.5/weather?q=ketchikan,us&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #57: mataura, pf
# http://api.openweathermap.org/data/2.5/weather?q=mataura,pf&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Error with city data... Skipping
# Now retrieving City #58: slave lake, ca
# http://api.openweathermap.org/data/2.5/weather?q=slave lake,ca&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #59: port macquarie, au
# http://api.openweathermap.org/data/2.5/weather?q=port macquarie,au&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #60: saint george, bm
# http://api.openweathermap.org/data/2.5/weather?q=saint george,bm&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #61: imperia, it
# http://api.openweathermap.org/data/2.5/weather?q=imperia,it&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #62: richards bay, za
# http://api.openweathermap.org/data/2.5/weather?q=richards bay,za&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #63: atuona, pf
# http://api.openweathermap.org/data/2.5/weather?q=atuona,pf&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #64: hermanus, za
# http://api.openweathermap.org/data/2.5/weather?q=hermanus,za&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #65: vaini, to
# http://api.openweathermap.org/data/2.5/weather?q=vaini,to&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #66: tuktoyaktuk, ca
# http://api.openweathermap.org/data/2.5/weather?q=tuktoyaktuk,ca&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #67: bambous virieux, mu
# http://api.openweathermap.org/data/2.5/weather?q=bambous virieux,mu&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #68: boyuibe, bo
# http://api.openweathermap.org/data/2.5/weather?q=boyuibe,bo&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #69: kodiak, us
# http://api.openweathermap.org/data/2.5/weather?q=kodiak,us&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #70: outjo, na
# http://api.openweathermap.org/data/2.5/weather?q=outjo,na&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #71: kavieng, pg
# http://api.openweathermap.org/data/2.5/weather?q=kavieng,pg&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #72: touros, br
# http://api.openweathermap.org/data/2.5/weather?q=touros,br&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #73: ostrovnoy, ru
# http://api.openweathermap.org/data/2.5/weather?q=ostrovnoy,ru&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #74: yulara, au
# http://api.openweathermap.org/data/2.5/weather?q=yulara,au&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #75: khani, ru
# http://api.openweathermap.org/data/2.5/weather?q=khani,ru&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Error with city data... Skipping
# Now retrieving City #76: luderitz, na
# http://api.openweathermap.org/data/2.5/weather?q=luderitz,na&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #77: cape town, za
# http://api.openweathermap.org/data/2.5/weather?q=cape town,za&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #78: arraial do cabo, br
# http://api.openweathermap.org/data/2.5/weather?q=arraial do cabo,br&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #79: tupancireta, br
# http://api.openweathermap.org/data/2.5/weather?q=tupancireta,br&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #80: lotofaga, ws
# http://api.openweathermap.org/data/2.5/weather?q=lotofaga,ws&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #81: bollnas, se
# http://api.openweathermap.org/data/2.5/weather?q=bollnas,se&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #82: jamestown, sh
# http://api.openweathermap.org/data/2.5/weather?q=jamestown,sh&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #83: dargaville, nz
# http://api.openweathermap.org/data/2.5/weather?q=dargaville,nz&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #84: tuatapere, nz
# http://api.openweathermap.org/data/2.5/weather?q=tuatapere,nz&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #85: vestmannaeyjar, is
# http://api.openweathermap.org/data/2.5/weather?q=vestmannaeyjar,is&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #86: iqaluit, ca
# http://api.openweathermap.org/data/2.5/weather?q=iqaluit,ca&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #87: hasaki, jp
# http://api.openweathermap.org/data/2.5/weather?q=hasaki,jp&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #88: stokmarknes, no
# http://api.openweathermap.org/data/2.5/weather?q=stokmarknes,no&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #89: grand river south east, mu
# http://api.openweathermap.org/data/2.5/weather?q=grand river south east,mu&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Error with city data... Skipping
# Now retrieving City #90: dingle, ie
# http://api.openweathermap.org/data/2.5/weather?q=dingle,ie&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #91: cabo san lucas, mx
# http://api.openweathermap.org/data/2.5/weather?q=cabo san lucas,mx&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #92: capitan bado, py
# http://api.openweathermap.org/data/2.5/weather?q=capitan bado,py&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #93: hithadhoo, mv
# http://api.openweathermap.org/data/2.5/weather?q=hithadhoo,mv&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #94: merauke, id
# http://api.openweathermap.org/data/2.5/weather?q=merauke,id&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #95: east london, za
# http://api.openweathermap.org/data/2.5/weather?q=east london,za&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #96: chokurdakh, ru
# http://api.openweathermap.org/data/2.5/weather?q=chokurdakh,ru&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #97: bombay, in
# http://api.openweathermap.org/data/2.5/weather?q=bombay,in&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Error with city data... Skipping
# Now retrieving City #98: georgetown, sh
# http://api.openweathermap.org/data/2.5/weather?q=georgetown,sh&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #99: lata, sb
# http://api.openweathermap.org/data/2.5/weather?q=lata,sb&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Error with city data... Skipping
# Now retrieving City #100: karratha, au
# http://api.openweathermap.org/data/2.5/weather?q=karratha,au&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #101: saskylakh, ru
# http://api.openweathermap.org/data/2.5/weather?q=saskylakh,ru&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #102: constitucion, mx
# http://api.openweathermap.org/data/2.5/weather?q=constitucion,mx&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #103: provideniya, ru
# http://api.openweathermap.org/data/2.5/weather?q=provideniya,ru&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #104: wahpeton, us
# http://api.openweathermap.org/data/2.5/weather?q=wahpeton,us&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #105: lakes entrance, au
# http://api.openweathermap.org/data/2.5/weather?q=lakes entrance,au&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #106: port lincoln, au
# http://api.openweathermap.org/data/2.5/weather?q=port lincoln,au&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #107: constantine, dz
# http://api.openweathermap.org/data/2.5/weather?q=constantine,dz&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #108: grand gaube, mu
# http://api.openweathermap.org/data/2.5/weather?q=grand gaube,mu&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #109: bonga, et
# http://api.openweathermap.org/data/2.5/weather?q=bonga,et&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #110: marawi, sd
# http://api.openweathermap.org/data/2.5/weather?q=marawi,sd&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #111: gamba, ga
# http://api.openweathermap.org/data/2.5/weather?q=gamba,ga&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #112: kahului, us
# http://api.openweathermap.org/data/2.5/weather?q=kahului,us&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #113: bengkulu, id
# http://api.openweathermap.org/data/2.5/weather?q=bengkulu,id&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Error with city data... Skipping
# Now retrieving City #114: taolanaro, mg
# http://api.openweathermap.org/data/2.5/weather?q=taolanaro,mg&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Error with city data... Skipping
# Now retrieving City #115: novikovo, ru
# http://api.openweathermap.org/data/2.5/weather?q=novikovo,ru&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #116: torbay, ca
# http://api.openweathermap.org/data/2.5/weather?q=torbay,ca&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #117: yumen, cn
# http://api.openweathermap.org/data/2.5/weather?q=yumen,cn&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #118: ahuimanu, us
# http://api.openweathermap.org/data/2.5/weather?q=ahuimanu,us&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #119: pershotravneve, ua
# http://api.openweathermap.org/data/2.5/weather?q=pershotravneve,ua&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #120: hilo, us
# http://api.openweathermap.org/data/2.5/weather?q=hilo,us&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #121: puerto ayora, ec
# http://api.openweathermap.org/data/2.5/weather?q=puerto ayora,ec&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #122: attawapiskat, ca
# http://api.openweathermap.org/data/2.5/weather?q=attawapiskat,ca&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Error with city data... Skipping
# Now retrieving City #123: sataua, ws
# http://api.openweathermap.org/data/2.5/weather?q=sataua,ws&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Error with city data... Skipping
# Now retrieving City #124: khatanga, ru
# http://api.openweathermap.org/data/2.5/weather?q=khatanga,ru&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #125: zaplyusye, ru
# http://api.openweathermap.org/data/2.5/weather?q=zaplyusye,ru&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Error with city data... Skipping
# Now retrieving City #126: west bay, ky
# http://api.openweathermap.org/data/2.5/weather?q=west bay,ky&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #127: mercedes, ar
# http://api.openweathermap.org/data/2.5/weather?q=mercedes,ar&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #128: punta arenas, cl
# http://api.openweathermap.org/data/2.5/weather?q=punta arenas,cl&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #129: swan river, ca
# http://api.openweathermap.org/data/2.5/weather?q=swan river,ca&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #130: namatanai, pg
# http://api.openweathermap.org/data/2.5/weather?q=namatanai,pg&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #131: rantepao, id
# http://api.openweathermap.org/data/2.5/weather?q=rantepao,id&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #132: lebu, cl
# http://api.openweathermap.org/data/2.5/weather?q=lebu,cl&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #133: bac lieu, vn
# http://api.openweathermap.org/data/2.5/weather?q=bac lieu,vn&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Error with city data... Skipping
# Now retrieving City #134: qaanaaq, gl
# http://api.openweathermap.org/data/2.5/weather?q=qaanaaq,gl&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #135: guanaja, hn
# http://api.openweathermap.org/data/2.5/weather?q=guanaja,hn&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #136: pacific grove, us
# http://api.openweathermap.org/data/2.5/weather?q=pacific grove,us&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #137: alofi, nu
# http://api.openweathermap.org/data/2.5/weather?q=alofi,nu&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #138: mar del plata, ar
# http://api.openweathermap.org/data/2.5/weather?q=mar del plata,ar&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #139: revda, ru
# http://api.openweathermap.org/data/2.5/weather?q=revda,ru&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #140: nizhniy tsasuchey, ru
# http://api.openweathermap.org/data/2.5/weather?q=nizhniy tsasuchey,ru&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #141: mandiana, gn
# http://api.openweathermap.org/data/2.5/weather?q=mandiana,gn&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #142: bahia blanca, ar
# http://api.openweathermap.org/data/2.5/weather?q=bahia blanca,ar&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #143: lanxi, cn
# http://api.openweathermap.org/data/2.5/weather?q=lanxi,cn&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #144: lompoc, us
# http://api.openweathermap.org/data/2.5/weather?q=lompoc,us&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #145: flowing wells, us
# http://api.openweathermap.org/data/2.5/weather?q=flowing wells,us&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #146: mogadishu, so
# http://api.openweathermap.org/data/2.5/weather?q=mogadishu,so&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #147: santa lucia, es
# http://api.openweathermap.org/data/2.5/weather?q=santa lucia,es&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #148: kaitangata, nz
# http://api.openweathermap.org/data/2.5/weather?q=kaitangata,nz&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #149: faanui, pf
# http://api.openweathermap.org/data/2.5/weather?q=faanui,pf&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #150: kalispell, us
# http://api.openweathermap.org/data/2.5/weather?q=kalispell,us&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #151: sokoni, tz
# http://api.openweathermap.org/data/2.5/weather?q=sokoni,tz&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Error with city data... Skipping
# Now retrieving City #152: kavaratti, in
# http://api.openweathermap.org/data/2.5/weather?q=kavaratti,in&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #153: cherskiy, ru
# http://api.openweathermap.org/data/2.5/weather?q=cherskiy,ru&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #154: tura, ru
# http://api.openweathermap.org/data/2.5/weather?q=tura,ru&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #155: am timan, td
# http://api.openweathermap.org/data/2.5/weather?q=am timan,td&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #156: ponta delgada, pt
# http://api.openweathermap.org/data/2.5/weather?q=ponta delgada,pt&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #157: avarua, ck
# http://api.openweathermap.org/data/2.5/weather?q=avarua,ck&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #158: mount isa, au
# http://api.openweathermap.org/data/2.5/weather?q=mount isa,au&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #159: taburi, ph
# http://api.openweathermap.org/data/2.5/weather?q=taburi,ph&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Error with city data... Skipping
# Now retrieving City #160: fortuna, us
# http://api.openweathermap.org/data/2.5/weather?q=fortuna,us&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #161: tual, id
# http://api.openweathermap.org/data/2.5/weather?q=tual,id&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #162: copiapo, cl
# http://api.openweathermap.org/data/2.5/weather?q=copiapo,cl&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #163: saldanha, za
# http://api.openweathermap.org/data/2.5/weather?q=saldanha,za&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #164: padang, id
# http://api.openweathermap.org/data/2.5/weather?q=padang,id&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #165: luang prabang, la
# http://api.openweathermap.org/data/2.5/weather?q=luang prabang,la&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #166: aklavik, ca
# http://api.openweathermap.org/data/2.5/weather?q=aklavik,ca&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #167: nenjiang, cn
# http://api.openweathermap.org/data/2.5/weather?q=nenjiang,cn&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #168: castro, cl
# http://api.openweathermap.org/data/2.5/weather?q=castro,cl&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #169: lorengau, pg
# http://api.openweathermap.org/data/2.5/weather?q=lorengau,pg&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #170: acapulco, mx
# http://api.openweathermap.org/data/2.5/weather?q=acapulco,mx&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #171: ilulissat, gl
# http://api.openweathermap.org/data/2.5/weather?q=ilulissat,gl&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #172: high level, ca
# http://api.openweathermap.org/data/2.5/weather?q=high level,ca&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #173: nautla, mx
# http://api.openweathermap.org/data/2.5/weather?q=nautla,mx&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #174: christchurch, nz
# http://api.openweathermap.org/data/2.5/weather?q=christchurch,nz&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #175: singkang, id
# http://api.openweathermap.org/data/2.5/weather?q=singkang,id&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Error with city data... Skipping
# Now retrieving City #176: zboriv, ua
# http://api.openweathermap.org/data/2.5/weather?q=zboriv,ua&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #177: umm lajj, sa
# http://api.openweathermap.org/data/2.5/weather?q=umm lajj,sa&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #178: le vauclin, mq
# http://api.openweathermap.org/data/2.5/weather?q=le vauclin,mq&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #179: olafsvik, is
# http://api.openweathermap.org/data/2.5/weather?q=olafsvik,is&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Error with city data... Skipping
# Now retrieving City #180: araouane, ml
# http://api.openweathermap.org/data/2.5/weather?q=araouane,ml&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #181: hanmer springs, nz
# http://api.openweathermap.org/data/2.5/weather?q=hanmer springs,nz&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #182: jutai, br
# http://api.openweathermap.org/data/2.5/weather?q=jutai,br&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #183: cobija, bo
# http://api.openweathermap.org/data/2.5/weather?q=cobija,bo&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #184: almiros, gr
# http://api.openweathermap.org/data/2.5/weather?q=almiros,gr&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Error with city data... Skipping
# Now retrieving City #185: caxito, ao
# http://api.openweathermap.org/data/2.5/weather?q=caxito,ao&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #186: dikson, ru
# http://api.openweathermap.org/data/2.5/weather?q=dikson,ru&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #187: nalut, ly
# http://api.openweathermap.org/data/2.5/weather?q=nalut,ly&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #188: saint-francois, gp
# http://api.openweathermap.org/data/2.5/weather?q=saint-francois,gp&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #189: olavarria, ar
# http://api.openweathermap.org/data/2.5/weather?q=olavarria,ar&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #190: calvinia, za
# http://api.openweathermap.org/data/2.5/weather?q=calvinia,za&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #191: gubkinskiy, ru
# http://api.openweathermap.org/data/2.5/weather?q=gubkinskiy,ru&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #192: bam, ir
# http://api.openweathermap.org/data/2.5/weather?q=bam,ir&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #193: tumannyy, ru
# http://api.openweathermap.org/data/2.5/weather?q=tumannyy,ru&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Error with city data... Skipping
# Now retrieving City #194: mabamba, tz
# http://api.openweathermap.org/data/2.5/weather?q=mabamba,tz&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #195: yar-sale, ru
# http://api.openweathermap.org/data/2.5/weather?q=yar-sale,ru&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #196: alice springs, au
# http://api.openweathermap.org/data/2.5/weather?q=alice springs,au&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #197: hastings, nz
# http://api.openweathermap.org/data/2.5/weather?q=hastings,nz&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #198: klaksvik, fo
# http://api.openweathermap.org/data/2.5/weather?q=klaksvik,fo&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #199: galiwinku, au
# http://api.openweathermap.org/data/2.5/weather?q=galiwinku,au&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Error with city data... Skipping
# Now retrieving City #200: vitim, ru
# http://api.openweathermap.org/data/2.5/weather?q=vitim,ru&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #201: deputatskiy, ru
# http://api.openweathermap.org/data/2.5/weather?q=deputatskiy,ru&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #202: jiwani, pk
# http://api.openweathermap.org/data/2.5/weather?q=jiwani,pk&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #203: grenville, gd
# http://api.openweathermap.org/data/2.5/weather?q=grenville,gd&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #204: inuvik, ca
# http://api.openweathermap.org/data/2.5/weather?q=inuvik,ca&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #205: samarai, pg
# http://api.openweathermap.org/data/2.5/weather?q=samarai,pg&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #206: tsihombe, mg
# http://api.openweathermap.org/data/2.5/weather?q=tsihombe,mg&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Error with city data... Skipping
# Now retrieving City #207: bethel, us
# http://api.openweathermap.org/data/2.5/weather?q=bethel,us&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #208: ola, ru
# http://api.openweathermap.org/data/2.5/weather?q=ola,ru&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #209: casimiro castillo, mx
# http://api.openweathermap.org/data/2.5/weather?q=casimiro castillo,mx&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #210: moquegua, pe
# http://api.openweathermap.org/data/2.5/weather?q=moquegua,pe&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #211: surt, ly
# http://api.openweathermap.org/data/2.5/weather?q=surt,ly&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #212: barentsburg, sj
# http://api.openweathermap.org/data/2.5/weather?q=barentsburg,sj&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Error with city data... Skipping
# Now retrieving City #213: svetlogorsk, ru
# http://api.openweathermap.org/data/2.5/weather?q=svetlogorsk,ru&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #214: belushya guba, ru
# http://api.openweathermap.org/data/2.5/weather?q=belushya guba,ru&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Error with city data... Skipping
# Now retrieving City #215: marzuq, ly
# http://api.openweathermap.org/data/2.5/weather?q=marzuq,ly&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Error with city data... Skipping
# Now retrieving City #216: colares, pt
# http://api.openweathermap.org/data/2.5/weather?q=colares,pt&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #217: harper, lr
# http://api.openweathermap.org/data/2.5/weather?q=harper,lr&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #218: asau, tv
# http://api.openweathermap.org/data/2.5/weather?q=asau,tv&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Error with city data... Skipping
# Now retrieving City #219: keti bandar, pk
# http://api.openweathermap.org/data/2.5/weather?q=keti bandar,pk&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #220: jaipur hat, bd
# http://api.openweathermap.org/data/2.5/weather?q=jaipur hat,bd&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Error with city data... Skipping
# Now retrieving City #221: fairbanks, us
# http://api.openweathermap.org/data/2.5/weather?q=fairbanks,us&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #222: pringsewu, id
# http://api.openweathermap.org/data/2.5/weather?q=pringsewu,id&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #223: zhezkazgan, kz
# http://api.openweathermap.org/data/2.5/weather?q=zhezkazgan,kz&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #224: kurgan, ru
# http://api.openweathermap.org/data/2.5/weather?q=kurgan,ru&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #225: chandpur, bd
# http://api.openweathermap.org/data/2.5/weather?q=chandpur,bd&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #226: ciudad bolivar, ve
# http://api.openweathermap.org/data/2.5/weather?q=ciudad bolivar,ve&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #227: kazalinsk, kz
# http://api.openweathermap.org/data/2.5/weather?q=kazalinsk,kz&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Error with city data... Skipping
# Now retrieving City #228: zhanaozen, kz
# http://api.openweathermap.org/data/2.5/weather?q=zhanaozen,kz&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #229: gigmoto, ph
# http://api.openweathermap.org/data/2.5/weather?q=gigmoto,ph&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #230: port hedland, au
# http://api.openweathermap.org/data/2.5/weather?q=port hedland,au&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #231: sentyabrskiy, ru
# http://api.openweathermap.org/data/2.5/weather?q=sentyabrskiy,ru&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Error with city data... Skipping
# Now retrieving City #232: yafran, ly
# http://api.openweathermap.org/data/2.5/weather?q=yafran,ly&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #233: nanortalik, gl
# http://api.openweathermap.org/data/2.5/weather?q=nanortalik,gl&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #234: mys shmidta, ru
# http://api.openweathermap.org/data/2.5/weather?q=mys shmidta,ru&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Error with city data... Skipping
# Now retrieving City #235: groningen, nl
# http://api.openweathermap.org/data/2.5/weather?q=groningen,nl&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #236: arrecife, es
# http://api.openweathermap.org/data/2.5/weather?q=arrecife,es&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #237: cayenne, gf
# http://api.openweathermap.org/data/2.5/weather?q=cayenne,gf&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #238: rungata, ki
# http://api.openweathermap.org/data/2.5/weather?q=rungata,ki&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Error with city data... Skipping
# Now retrieving City #239: adrar, dz
# http://api.openweathermap.org/data/2.5/weather?q=adrar,dz&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #240: anloga, gh
# http://api.openweathermap.org/data/2.5/weather?q=anloga,gh&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #241: asayita, et
# http://api.openweathermap.org/data/2.5/weather?q=asayita,et&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Error with city data... Skipping
# Now retrieving City #242: nizhneyansk, ru
# http://api.openweathermap.org/data/2.5/weather?q=nizhneyansk,ru&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Error with city data... Skipping
# Now retrieving City #243: sorokino, ru
# http://api.openweathermap.org/data/2.5/weather?q=sorokino,ru&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #244: taksimo, ru
# http://api.openweathermap.org/data/2.5/weather?q=taksimo,ru&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #245: kununurra, au
# http://api.openweathermap.org/data/2.5/weather?q=kununurra,au&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #246: ksenyevka, ru
# http://api.openweathermap.org/data/2.5/weather?q=ksenyevka,ru&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Error with city data... Skipping
# Now retrieving City #247: nhamunda, br
# http://api.openweathermap.org/data/2.5/weather?q=nhamunda,br&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #248: stoyba, ru
# http://api.openweathermap.org/data/2.5/weather?q=stoyba,ru&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Error with city data... Skipping
# Now retrieving City #249: goryachiy klyuch, ru
# http://api.openweathermap.org/data/2.5/weather?q=goryachiy klyuch,ru&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #250: souillac, mu
# http://api.openweathermap.org/data/2.5/weather?q=souillac,mu&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #251: tranas, se
# http://api.openweathermap.org/data/2.5/weather?q=tranas,se&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #252: limot, ph
# http://api.openweathermap.org/data/2.5/weather?q=limot,ph&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #253: atherton, au
# http://api.openweathermap.org/data/2.5/weather?q=atherton,au&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #254: evanston, us
# http://api.openweathermap.org/data/2.5/weather?q=evanston,us&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #255: bluff, nz
# http://api.openweathermap.org/data/2.5/weather?q=bluff,nz&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #256: raga, sd
# http://api.openweathermap.org/data/2.5/weather?q=raga,sd&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Error with city data... Skipping
# Now retrieving City #257: sirnak, tr
# http://api.openweathermap.org/data/2.5/weather?q=sirnak,tr&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #258: saurimo, ao
# http://api.openweathermap.org/data/2.5/weather?q=saurimo,ao&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #259: hammerfest, no
# http://api.openweathermap.org/data/2.5/weather?q=hammerfest,no&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #260: illoqqortoormiut, gl
# http://api.openweathermap.org/data/2.5/weather?q=illoqqortoormiut,gl&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Error with city data... Skipping
# Now retrieving City #261: pevek, ru
# http://api.openweathermap.org/data/2.5/weather?q=pevek,ru&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #262: cabinda, ao
# http://api.openweathermap.org/data/2.5/weather?q=cabinda,ao&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #263: ust-nera, ru
# http://api.openweathermap.org/data/2.5/weather?q=ust-nera,ru&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #264: lac du bonnet, ca
# http://api.openweathermap.org/data/2.5/weather?q=lac du bonnet,ca&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #265: samusu, ws
# http://api.openweathermap.org/data/2.5/weather?q=samusu,ws&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Error with city data... Skipping
# Now retrieving City #266: noumea, nc
# http://api.openweathermap.org/data/2.5/weather?q=noumea,nc&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #267: zhigansk, ru
# http://api.openweathermap.org/data/2.5/weather?q=zhigansk,ru&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #268: narsaq, gl
# http://api.openweathermap.org/data/2.5/weather?q=narsaq,gl&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #269: pirgos, gr
# http://api.openweathermap.org/data/2.5/weather?q=pirgos,gr&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #270: eydhafushi, mv
# http://api.openweathermap.org/data/2.5/weather?q=eydhafushi,mv&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #271: morros, br
# http://api.openweathermap.org/data/2.5/weather?q=morros,br&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #272: tezu, in
# http://api.openweathermap.org/data/2.5/weather?q=tezu,in&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #273: san patricio, mx
# http://api.openweathermap.org/data/2.5/weather?q=san patricio,mx&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #274: srednekolymsk, ru
# http://api.openweathermap.org/data/2.5/weather?q=srednekolymsk,ru&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #275: cidreira, br
# http://api.openweathermap.org/data/2.5/weather?q=cidreira,br&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #276: port augusta, au
# http://api.openweathermap.org/data/2.5/weather?q=port augusta,au&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #277: kemijarvi, fi
# http://api.openweathermap.org/data/2.5/weather?q=kemijarvi,fi&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Error with city data... Skipping
# Now retrieving City #278: nema, ru
# http://api.openweathermap.org/data/2.5/weather?q=nema,ru&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #279: bosaso, so
# http://api.openweathermap.org/data/2.5/weather?q=bosaso,so&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #280: toungoo, mm
# http://api.openweathermap.org/data/2.5/weather?q=toungoo,mm&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Error with city data... Skipping
# Now retrieving City #281: rio gallegos, ar
# http://api.openweathermap.org/data/2.5/weather?q=rio gallegos,ar&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #282: carnarvon, au
# http://api.openweathermap.org/data/2.5/weather?q=carnarvon,au&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #283: tasiilaq, gl
# http://api.openweathermap.org/data/2.5/weather?q=tasiilaq,gl&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #284: bismarck, us
# http://api.openweathermap.org/data/2.5/weather?q=bismarck,us&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #285: abha, sa
# http://api.openweathermap.org/data/2.5/weather?q=abha,sa&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #286: nguiu, au
# http://api.openweathermap.org/data/2.5/weather?q=nguiu,au&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Error with city data... Skipping
# Now retrieving City #287: mahadday weyne, so
# http://api.openweathermap.org/data/2.5/weather?q=mahadday weyne,so&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Error with city data... Skipping
# Now retrieving City #288: hamilton, bm
# http://api.openweathermap.org/data/2.5/weather?q=hamilton,bm&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #289: kalach-na-donu, ru
# http://api.openweathermap.org/data/2.5/weather?q=kalach-na-donu,ru&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #290: grindavik, is
# http://api.openweathermap.org/data/2.5/weather?q=grindavik,is&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #291: kloulklubed, pw
# http://api.openweathermap.org/data/2.5/weather?q=kloulklubed,pw&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #292: longyearbyen, sj
# http://api.openweathermap.org/data/2.5/weather?q=longyearbyen,sj&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #293: nabire, id
# http://api.openweathermap.org/data/2.5/weather?q=nabire,id&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #294: palabuhanratu, id
# http://api.openweathermap.org/data/2.5/weather?q=palabuhanratu,id&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# ...
# Now retrieving City #540: prince rupert, ca
# http://api.openweathermap.org/data/2.5/weather?q=prince rupert,ca&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #541: port blair, in
# http://api.openweathermap.org/data/2.5/weather?q=port blair,in&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #542: marsa matruh, eg
# http://api.openweathermap.org/data/2.5/weather?q=marsa matruh,eg&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #543: makhinjauri, ge
# http://api.openweathermap.org/data/2.5/weather?q=makhinjauri,ge&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #544: zalantun, cn
# http://api.openweathermap.org/data/2.5/weather?q=zalantun,cn&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #545: jeremie, ht
# http://api.openweathermap.org/data/2.5/weather?q=jeremie,ht&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #546: chifeng, cn
# http://api.openweathermap.org/data/2.5/weather?q=chifeng,cn&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #547: college, us
# http://api.openweathermap.org/data/2.5/weather?q=college,us&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #548: nyurba, ru
# http://api.openweathermap.org/data/2.5/weather?q=nyurba,ru&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #549: morondava, mg
# http://api.openweathermap.org/data/2.5/weather?q=morondava,mg&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #550: usinsk, ru
# http://api.openweathermap.org/data/2.5/weather?q=usinsk,ru&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #551: banda aceh, id
# http://api.openweathermap.org/data/2.5/weather?q=banda aceh,id&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #552: berlevag, no
# http://api.openweathermap.org/data/2.5/weather?q=berlevag,no&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #553: hirara, jp
# http://api.openweathermap.org/data/2.5/weather?q=hirara,jp&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #554: ihosy, mg
# http://api.openweathermap.org/data/2.5/weather?q=ihosy,mg&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #555: port hardy, ca
# http://api.openweathermap.org/data/2.5/weather?q=port hardy,ca&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #556: faya, td
# http://api.openweathermap.org/data/2.5/weather?q=faya,td&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Error with city data... Skipping
# Now retrieving City #557: saint george, us
# http://api.openweathermap.org/data/2.5/weather?q=saint george,us&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #558: george, za
# http://api.openweathermap.org/data/2.5/weather?q=george,za&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #559: ambon, id
# http://api.openweathermap.org/data/2.5/weather?q=ambon,id&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #560: grand forks, us
# http://api.openweathermap.org/data/2.5/weather?q=grand forks,us&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #561: ternate, id
# http://api.openweathermap.org/data/2.5/weather?q=ternate,id&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #562: warqla, dz
# http://api.openweathermap.org/data/2.5/weather?q=warqla,dz&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Error with city data... Skipping
# Now retrieving City #563: nantucket, us
# http://api.openweathermap.org/data/2.5/weather?q=nantucket,us&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #564: geraldton, au
# http://api.openweathermap.org/data/2.5/weather?q=geraldton,au&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #565: beaverton, ca
# http://api.openweathermap.org/data/2.5/weather?q=beaverton,ca&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #566: ambilobe, mg
# http://api.openweathermap.org/data/2.5/weather?q=ambilobe,mg&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #567: bulgan, mn
# http://api.openweathermap.org/data/2.5/weather?q=bulgan,mn&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #568: lubyany, ru
# http://api.openweathermap.org/data/2.5/weather?q=lubyany,ru&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #569: lagoa, pt
# http://api.openweathermap.org/data/2.5/weather?q=lagoa,pt&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #570: bonthe, sl
# http://api.openweathermap.org/data/2.5/weather?q=bonthe,sl&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #571: kautokeino, no
# http://api.openweathermap.org/data/2.5/weather?q=kautokeino,no&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #572: yellandu, in
# http://api.openweathermap.org/data/2.5/weather?q=yellandu,in&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #573: raudeberg, no
# http://api.openweathermap.org/data/2.5/weather?q=raudeberg,no&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #574: porangatu, br
# http://api.openweathermap.org/data/2.5/weather?q=porangatu,br&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #575: virginia beach, us
# http://api.openweathermap.org/data/2.5/weather?q=virginia beach,us&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #576: egvekinot, ru
# http://api.openweathermap.org/data/2.5/weather?q=egvekinot,ru&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #577: riyadh, sa
# http://api.openweathermap.org/data/2.5/weather?q=riyadh,sa&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #578: lalmohan, bd
# http://api.openweathermap.org/data/2.5/weather?q=lalmohan,bd&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #579: ancud, cl
# http://api.openweathermap.org/data/2.5/weather?q=ancud,cl&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #580: khandbari, np
# http://api.openweathermap.org/data/2.5/weather?q=khandbari,np&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #581: rogozno, pl
# http://api.openweathermap.org/data/2.5/weather?q=rogozno,pl&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #582: harlingen, nl
# http://api.openweathermap.org/data/2.5/weather?q=harlingen,nl&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #583: mangai, cd
# http://api.openweathermap.org/data/2.5/weather?q=mangai,cd&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #584: grand-santi, gf
# http://api.openweathermap.org/data/2.5/weather?q=grand-santi,gf&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #585: alekseyevka, ru
# http://api.openweathermap.org/data/2.5/weather?q=alekseyevka,ru&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #586: yaroslavl, ru
# http://api.openweathermap.org/data/2.5/weather?q=yaroslavl,ru&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #587: mitsamiouli, km
# http://api.openweathermap.org/data/2.5/weather?q=mitsamiouli,km&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #588: varhaug, no
# http://api.openweathermap.org/data/2.5/weather?q=varhaug,no&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #589: ishigaki, jp
# http://api.openweathermap.org/data/2.5/weather?q=ishigaki,jp&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #590: concepcion, py
# http://api.openweathermap.org/data/2.5/weather?q=concepcion,py&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #591: jega, ng
# http://api.openweathermap.org/data/2.5/weather?q=jega,ng&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #592: skjervoy, no
# http://api.openweathermap.org/data/2.5/weather?q=skjervoy,no&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #593: satka, ru
# http://api.openweathermap.org/data/2.5/weather?q=satka,ru&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #594: rojhan, pk
# http://api.openweathermap.org/data/2.5/weather?q=rojhan,pk&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #595: hami, cn
# http://api.openweathermap.org/data/2.5/weather?q=hami,cn&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #596: sao domingos do maranhao, br
# http://api.openweathermap.org/data/2.5/weather?q=sao domingos do maranhao,br&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #597: samarinda, id
# http://api.openweathermap.org/data/2.5/weather?q=samarinda,id&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #598: kidal, ml
# http://api.openweathermap.org/data/2.5/weather?q=kidal,ml&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #599: lerwick, gb
# http://api.openweathermap.org/data/2.5/weather?q=lerwick,gb&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #600: koulikoro, ml
# http://api.openweathermap.org/data/2.5/weather?q=koulikoro,ml&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #601: benguela, ao
# http://api.openweathermap.org/data/2.5/weather?q=benguela,ao&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #602: sept-iles, ca
# http://api.openweathermap.org/data/2.5/weather?q=sept-iles,ca&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #603: emba, kz
# http://api.openweathermap.org/data/2.5/weather?q=emba,kz&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Error with city data... Skipping
# Now retrieving City #604: toliary, mg
# http://api.openweathermap.org/data/2.5/weather?q=toliary,mg&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Error with city data... Skipping
# Now retrieving City #605: gerash, ir
# http://api.openweathermap.org/data/2.5/weather?q=gerash,ir&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #606: baiyin, cn
# http://api.openweathermap.org/data/2.5/weather?q=baiyin,cn&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #607: abu dhabi, ae
# http://api.openweathermap.org/data/2.5/weather?q=abu dhabi,ae&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #608: tahoua, ne
# http://api.openweathermap.org/data/2.5/weather?q=tahoua,ne&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #609: los llanos de aridane, es
# http://api.openweathermap.org/data/2.5/weather?q=los llanos de aridane,es&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #610: barinas, ve
# http://api.openweathermap.org/data/2.5/weather?q=barinas,ve&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #611: boffa, gn
# http://api.openweathermap.org/data/2.5/weather?q=boffa,gn&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #612: saint-louis, sn
# http://api.openweathermap.org/data/2.5/weather?q=saint-louis,sn&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #613: ozinki, ru
# http://api.openweathermap.org/data/2.5/weather?q=ozinki,ru&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #614: skalistyy, ru
# http://api.openweathermap.org/data/2.5/weather?q=skalistyy,ru&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Error with city data... Skipping
# Now retrieving City #615: urucara, br
# http://api.openweathermap.org/data/2.5/weather?q=urucara,br&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #616: mocuba, mz
# http://api.openweathermap.org/data/2.5/weather?q=mocuba,mz&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #617: zadar, hr
# http://api.openweathermap.org/data/2.5/weather?q=zadar,hr&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #618: bela vista, br
# http://api.openweathermap.org/data/2.5/weather?q=bela vista,br&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #619: oksovskiy, ru
# http://api.openweathermap.org/data/2.5/weather?q=oksovskiy,ru&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #620: mersing, my
# http://api.openweathermap.org/data/2.5/weather?q=mersing,my&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #621: haradok, by
# http://api.openweathermap.org/data/2.5/weather?q=haradok,by&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #622: arman, ru
# http://api.openweathermap.org/data/2.5/weather?q=arman,ru&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #623: minab, ir
# http://api.openweathermap.org/data/2.5/weather?q=minab,ir&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #624: henties bay, na
# http://api.openweathermap.org/data/2.5/weather?q=henties bay,na&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #625: mont-dore, nc
# http://api.openweathermap.org/data/2.5/weather?q=mont-dore,nc&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #626: sorland, no
# http://api.openweathermap.org/data/2.5/weather?q=sorland,no&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #627: marquette, us
# http://api.openweathermap.org/data/2.5/weather?q=marquette,us&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #628: waw, sd
# http://api.openweathermap.org/data/2.5/weather?q=waw,sd&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Error with city data... Skipping
# Now retrieving City #629: yerbogachen, ru
# http://api.openweathermap.org/data/2.5/weather?q=yerbogachen,ru&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #630: ekhabi, ru
# http://api.openweathermap.org/data/2.5/weather?q=ekhabi,ru&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #631: krasnoselkup, ru
# http://api.openweathermap.org/data/2.5/weather?q=krasnoselkup,ru&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Error with city data... Skipping
# Now retrieving City #632: uk, ru
# http://api.openweathermap.org/data/2.5/weather?q=uk,ru&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #633: sarangani, ph
# http://api.openweathermap.org/data/2.5/weather?q=sarangani,ph&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #634: atakpame, tg
# http://api.openweathermap.org/data/2.5/weather?q=atakpame,tg&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #635: kunnamangalam, in
# http://api.openweathermap.org/data/2.5/weather?q=kunnamangalam,in&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #636: belaya gora, ru
# http://api.openweathermap.org/data/2.5/weather?q=belaya gora,ru&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #637: sibolga, id
# http://api.openweathermap.org/data/2.5/weather?q=sibolga,id&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #638: beringovskiy, ru
# http://api.openweathermap.org/data/2.5/weather?q=beringovskiy,ru&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #639: vila, vu
# http://api.openweathermap.org/data/2.5/weather?q=vila,vu&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Error with city data... Skipping
# Now retrieving City #640: garissa, ke
# http://api.openweathermap.org/data/2.5/weather?q=garissa,ke&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# ---------------------------------------------------------------
# Data Retrieval Complete
# ---------------------------------------------------------------

# %%
#Drop NaN values from DataFrame
cities_df.dropna(inplace=True)

#Display final DataFrame
cities_df.head()
# Out:
#             City Country  Latitude  Longitude  Temperature (F)  Humidity (%)  \
# 0      maniitsoq      gl     66.47     -50.79             6.84          86.0
# 1        ushuaia      ar    -64.33     -59.44            46.40          61.0
# 2  san cristobal      ec     -9.74     -88.73            62.28         100.0
# 3          tiksi      ru     72.64     127.00             1.98          68.0
# 4    fort nelson      ca     62.72    -121.63            23.00          57.0
#
#    Cloudiness (%)  Wind Speed (mph)
# 0            76.0              6.06
# 1            75.0              6.93
# 2           100.0              2.33
# 3             0.0             14.12
# 4            20.0              3.36

# %%
#Check for missing values in DataFrame
cities_df.count()
# Out:
# City                572
# Country             572
# Latitude            572
# Longitude           572
# Temperature (F)     572
# Humidity (%)        572
# Cloudiness (%)      572
# Wind Speed (mph)    572
# dtype: int64

# %%
#Export DataFrame as CSV
cities_df.to_csv("Output/city_weather_info.csv")

# %% [markdown]
# ### Latitude vs Temperature Plot

# %%
#Define axis values
x_axis = cities_df["Latitude"]
y_axis = cities_df["Temperature (F)"]

#Set size of scatter plots
plt.figure(figsize=(10,6))

#Create scatter plot
plt.scatter(x_axis, y_axis, color="navy", edgecolors="black")

#Aesthetics
plt.title("City Latitude vs Temperature " + "(" + time.strftime("%m/%d/%Y") + ")", fontsize=20)
plt.xlabel("Latitude", fontsize=14)
plt.xlim(-80,100)
plt.ylabel("Temperature (F)", fontsize=14)
plt.ylim(-100,150)

#Save plot as PNG image
plt.savefig("Images/Latitude_vs_Temperature.png")

plt.grid()
plt.show()

# %% [markdown]
# ### Latitude vs Humidity Plot

# %%
#Define axis values
x_axis = cities_df["Latitude"]
y_axis = cities_df["Humidity (%)"]

#Set size of scatter plots
plt.figure(figsize=(10,6))

#Create scatter plot
plt.scatter(x_axis, y_axis, color="green", edgecolors="black")

#Aesthetics
plt.title("City Latitude vs Humidity " + "(" + time.strftime("%m/%d/%Y") + ")", fontsize=20)
plt.xlabel("Latitude", fontsize=14)
plt.xlim(-80,100)
plt.ylabel("Humidity (%)", fontsize=14)
plt.ylim(-20,125)

#Save plot as PNG image
plt.savefig("Images/Latitude_vs_Humidity.png")

plt.grid()
plt.show()

# %% [markdown]
# ### Latitude vs Cloudiness Plot

# %%
#Define axis values
x_axis = cities_df["Latitude"]
y_axis = cities_df["Cloudiness (%)"]

#Set size of scatter plots
plt.figure(figsize=(10,6))

#Create scatter plot
plt.scatter(x_axis, y_axis, color="blue", edgecolors="black")

#Aesthetics
plt.title("City Latitude vs Cloudiness " + "(" + time.strftime("%m/%d/%Y") + ")", fontsize=20)
plt.xlabel("Latitude", fontsize=14)
plt.xlim(-80,100)
plt.ylabel("Cloudiness (%)", fontsize=14)
plt.ylim(-20,125)

#Save plot as PNG image
plt.savefig("Images/Latitude_vs_Cloudiness.png")

plt.grid()
plt.show()

# %% [markdown]
# ### Latitude vs Wind Speed Plot

# %%
#Define axis values
x_axis = cities_df["Latitude"]
y_axis = cities_df["Wind Speed (mph)"]

#Set size of scatter plots
plt.figure(figsize=(10,6))

#Create scatter plot
plt.scatter(x_axis, y_axis, color="orange", edgecolors="black")

#Aesthetics
plt.title("City Latitude vs Wind Speed " + "(" + time.strftime("%m/%d/%Y") + ")", fontsize=20)
plt.xlabel("Latitude", fontsize=14)
plt.xlim(-80,100)
plt.ylabel("Wind Speed (mph)", fontsize=14)
plt.ylim(-5,40)

#Save plot as PNG image
plt.savefig("Images/Latitude_vs_WindSpeed.png")

plt.grid()
plt.show()

# %% [markdown]
# ### *****BONUS*****
# -  CHECK TO SEE IF THERE IS A SIGNIFICANT CORRELATION BETWEEN TEMPERATURE AND CLOUDINESS

# %%
#Define axis values
x_axis = cities_df["Latitude"]
y_axis = cities_df["Temperature (F)"]

#Set size of scatter plots
plt.figure(figsize=(10,6))

#Create scatter plot
plt.scatter(x_axis, y_axis, color="red", edgecolors="black")

#Define axis values
x_axis1 = cities_df["Latitude"]
y_axis2 = cities_df["Cloudiness (%)"]

#Create scatter plot
plt.scatter(x_axis1, y_axis2, color="blue", edgecolors="black")

#Aesthetics
plt.title("City Latitude vs Cloudiness/Temperature " + "(" + time.strftime("%m/%d/%Y") + ")", fontsize=20)
plt.xlabel("Latitude", fontsize=14)
plt.xlim(-80,100)
plt.ylabel("Cloudiness (%): blue, Temperature (F): red", fontsize=14)
plt.ylim(-20,125)

plt.grid()
plt.show()
