# %% [markdown]
# # WeatherPy
#
# ### Analysis
# -  Looking at the City Latitude vs Temperature scatterplot, it is made evident that the closer a city is to the equator (x-value = 0), the higher the temperature of the city is.
# -
# -  Too be completed
# -  Too be completed

# %%
#Install citipy library
# !pip install citipy

#Dependencies
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import requests
import time

from citipy import citipy
from pprint import pprint

#Import API key for OpenWeatherMapy
from config import owm_key
# Out:
# Requirement already satisfied: citipy in c:\users\austi\anaconda3\envs\pythondata\lib\site-packages
# Requirement already satisfied: kdtree>=0.12 in c:\users\austi\anaconda3\envs\pythondata\lib\site-packages (from citipy)
# You are using pip version 9.0.1, however version 9.0.3 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %% [markdown]
# ### Generate Cities List

# %%
#Create DataFrame
cities_df = pd.DataFrame()

#Add columns for City and Country
cities_df["City"] = ""
cities_df["Country"] = ""

#Generate 500+ random latitudes and longitudes, then add new columns and values to Dataframe
cities_df["Latitude"] = np.random.uniform(low=-90, high=90, size=1500)
cities_df["Longitude"] = np.random.uniform(low=-180, high=180, size=1500)
cities_df = round(cities_df, 2)

#Add columns to DataFrame for wanted values
cities_df["Temperature (F)"] = ""
cities_df["Humidity (%)"] = ""
cities_df["Cloudiness (%)"] = ""
cities_df["Wind Speed (mph)"] = ""

#Find and add nearest city & country based on the randomly selected lat and lng
for index, row in cities_df.iterrows():
    lat = row["Latitude"]
    lng = row["Longitude"]
    cities_df.set_value(index, "City", citipy.nearest_city(lat, lng).city_name)
    cities_df.set_value(index, "Country", citipy.nearest_city(lat, lng).country_code)

#Drop duplicate cities
cities_df.drop_duplicates(["City", "Country"], inplace=True)
cities_df.reset_index(inplace=True)

#Delete unneccesary column for aesthetics 
del cities_df["index"]

#Display updated DataFrame
cities_df.head()
# Out:
# C:\Users\austi\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:23: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Users\austi\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:24: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#                City Country  Latitude  Longitude Temperature (F) Humidity (%)  \
# 0       antofagasta      cl    -23.77     -72.90
# 1              hilo      us      2.12    -159.92
# 2  illoqqortoormiut      gl     88.70     -10.13
# 3             kapaa      us     14.44    -176.99
# 4           mataura      pf    -63.59    -151.32
#
#   Cloudiness (%) Wind Speed (mph)
# 0
# 1
# 2
# 3
# 4

# %%
#Check to be sure we have 500+ cities for dataset
len(cities_df)
# Out:
# 627

# %% [markdown]
# ### Perform API Calls

# %%
#Config info
units = "imperial"

#Access the data from openweathermapy
print("Beginning Data Retrieval")
print("---------------------------------------------------------------")

for index, row in cities_df.iterrows():
    #Target URL
    query_url = "http://api.openweathermap.org/data/2.5/weather?q=%s,%s&units=%s&appid=%s" % (row["City"], row["Country"], units, owm_key)
    
    #Print log of cities being processed
    print(f"Now retrieving City #" + str(index) + ": " + row["City"] + ", " + row["Country"])
    print(query_url)
    
    #Run requests to API
    weather_data = requests.get(query_url).json()
    
    #Use exceptional handling  to calculate and append values to DataFrame
    try:
        response = weather_data
        cities_df.set_value(index, "Temperature (F)", response["main"]["temp"])
        cities_df.set_value(index, "Humidity (%)", response["main"]["humidity"])
        cities_df.set_value(index, "Cloudiness (%)", response["clouds"]["all"])
        cities_df.set_value(index, "Wind Speed (mph)", response["wind"]["speed"])
    except:
        print("Error with city data... Skipping")
    
    
print("---------------------------------------------------------------")
print("Data Retrieval Complete")
print("---------------------------------------------------------------")  

#Covert strings to floats for DataFrame
columns = ["Latitude", "Longitude", "Temperature (F)", "Humidity (%)", "Cloudiness (%)", "Wind Speed (mph)"]
for column in columns:
    cities_df[column] = pd.to_numeric(cities_df[column], errors="coerce")
# Out:
# Beginning Data Retrieval
# ---------------------------------------------------------------
# Now retrieving City #0: antofagasta, cl
# http://api.openweathermap.org/data/2.5/weather?q=antofagasta,cl&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #1: hilo, us
# http://api.openweathermap.org/data/2.5/weather?q=hilo,us&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# C:\Users\austi\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:22: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Users\austi\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:23: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Users\austi\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:24: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Users\austi\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:25: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# Now retrieving City #2: illoqqortoormiut, gl
# http://api.openweathermap.org/data/2.5/weather?q=illoqqortoormiut,gl&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Error with city data... Skipping
# Now retrieving City #3: kapaa, us
# http://api.openweathermap.org/data/2.5/weather?q=kapaa,us&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #4: mataura, pf
# http://api.openweathermap.org/data/2.5/weather?q=mataura,pf&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Error with city data... Skipping
# Now retrieving City #5: saleaula, ws
# http://api.openweathermap.org/data/2.5/weather?q=saleaula,ws&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Error with city data... Skipping
# Now retrieving City #6: eyl, so
# http://api.openweathermap.org/data/2.5/weather?q=eyl,so&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #7: qaanaaq, gl
# http://api.openweathermap.org/data/2.5/weather?q=qaanaaq,gl&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #8: kolomak, ua
# http://api.openweathermap.org/data/2.5/weather?q=kolomak,ua&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #9: dikson, ru
# http://api.openweathermap.org/data/2.5/weather?q=dikson,ru&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #10: homer, us
# http://api.openweathermap.org/data/2.5/weather?q=homer,us&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #11: mar del plata, ar
# http://api.openweathermap.org/data/2.5/weather?q=mar del plata,ar&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #12: port elizabeth, za
# http://api.openweathermap.org/data/2.5/weather?q=port elizabeth,za&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #13: nguiu, au
# http://api.openweathermap.org/data/2.5/weather?q=nguiu,au&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Error with city data... Skipping
# Now retrieving City #14: geraldton, ca
# http://api.openweathermap.org/data/2.5/weather?q=geraldton,ca&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #15: saint-philippe, re
# http://api.openweathermap.org/data/2.5/weather?q=saint-philippe,re&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #16: cape town, za
# http://api.openweathermap.org/data/2.5/weather?q=cape town,za&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #17: albany, au
# http://api.openweathermap.org/data/2.5/weather?q=albany,au&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #18: amapa, br
# http://api.openweathermap.org/data/2.5/weather?q=amapa,br&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #19: toora-khem, ru
# http://api.openweathermap.org/data/2.5/weather?q=toora-khem,ru&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #20: fort nelson, ca
# http://api.openweathermap.org/data/2.5/weather?q=fort nelson,ca&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #21: timizart, dz
# http://api.openweathermap.org/data/2.5/weather?q=timizart,dz&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #22: nador, ma
# http://api.openweathermap.org/data/2.5/weather?q=nador,ma&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #23: vaini, to
# http://api.openweathermap.org/data/2.5/weather?q=vaini,to&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #24: bengkulu, id
# http://api.openweathermap.org/data/2.5/weather?q=bengkulu,id&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Error with city data... Skipping
# Now retrieving City #25: butaritari, ki
# http://api.openweathermap.org/data/2.5/weather?q=butaritari,ki&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #26: vernon, us
# http://api.openweathermap.org/data/2.5/weather?q=vernon,us&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #27: luau, ao
# http://api.openweathermap.org/data/2.5/weather?q=luau,ao&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #28: hermanus, za
# http://api.openweathermap.org/data/2.5/weather?q=hermanus,za&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #29: sitka, us
# http://api.openweathermap.org/data/2.5/weather?q=sitka,us&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #30: rio gallegos, ar
# http://api.openweathermap.org/data/2.5/weather?q=rio gallegos,ar&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #31: borogontsy, ru
# http://api.openweathermap.org/data/2.5/weather?q=borogontsy,ru&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #32: tuatapere, nz
# http://api.openweathermap.org/data/2.5/weather?q=tuatapere,nz&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #33: port alfred, za
# http://api.openweathermap.org/data/2.5/weather?q=port alfred,za&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #34: cherskiy, ru
# http://api.openweathermap.org/data/2.5/weather?q=cherskiy,ru&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #35: leningradskiy, ru
# http://api.openweathermap.org/data/2.5/weather?q=leningradskiy,ru&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #36: atuona, pf
# http://api.openweathermap.org/data/2.5/weather?q=atuona,pf&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #37: rikitea, pf
# http://api.openweathermap.org/data/2.5/weather?q=rikitea,pf&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #38: shache, cn
# http://api.openweathermap.org/data/2.5/weather?q=shache,cn&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #39: riachao, br
# http://api.openweathermap.org/data/2.5/weather?q=riachao,br&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #40: leninskoye, ru
# http://api.openweathermap.org/data/2.5/weather?q=leninskoye,ru&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #41: jamestown, sh
# http://api.openweathermap.org/data/2.5/weather?q=jamestown,sh&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #42: castro, cl
# http://api.openweathermap.org/data/2.5/weather?q=castro,cl&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #43: ushuaia, ar
# http://api.openweathermap.org/data/2.5/weather?q=ushuaia,ar&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #44: staritsa, ru
# http://api.openweathermap.org/data/2.5/weather?q=staritsa,ru&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #45: sopelana, es
# http://api.openweathermap.org/data/2.5/weather?q=sopelana,es&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #46: bambous virieux, mu
# http://api.openweathermap.org/data/2.5/weather?q=bambous virieux,mu&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #47: acarau, br
# http://api.openweathermap.org/data/2.5/weather?q=acarau,br&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Error with city data... Skipping
# Now retrieving City #48: hithadhoo, mv
# http://api.openweathermap.org/data/2.5/weather?q=hithadhoo,mv&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #49: hobart, au
# http://api.openweathermap.org/data/2.5/weather?q=hobart,au&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #50: cidreira, br
# http://api.openweathermap.org/data/2.5/weather?q=cidreira,br&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #51: barrow, us
# http://api.openweathermap.org/data/2.5/weather?q=barrow,us&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #52: union, us
# http://api.openweathermap.org/data/2.5/weather?q=union,us&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #53: portland, au
# http://api.openweathermap.org/data/2.5/weather?q=portland,au&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #54: anadyr, ru
# http://api.openweathermap.org/data/2.5/weather?q=anadyr,ru&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #55: bluff, nz
# http://api.openweathermap.org/data/2.5/weather?q=bluff,nz&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #56: bredasdorp, za
# http://api.openweathermap.org/data/2.5/weather?q=bredasdorp,za&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #57: formoso do araguaia, br
# http://api.openweathermap.org/data/2.5/weather?q=formoso do araguaia,br&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Error with city data... Skipping
# Now retrieving City #58: mahadday weyne, so
# http://api.openweathermap.org/data/2.5/weather?q=mahadday weyne,so&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Error with city data... Skipping
# Now retrieving City #59: punta arenas, cl
# http://api.openweathermap.org/data/2.5/weather?q=punta arenas,cl&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #60: east london, za
# http://api.openweathermap.org/data/2.5/weather?q=east london,za&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #61: karaul, ru
# http://api.openweathermap.org/data/2.5/weather?q=karaul,ru&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Error with city data... Skipping
# Now retrieving City #62: college, us
# http://api.openweathermap.org/data/2.5/weather?q=college,us&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #63: naze, jp
# http://api.openweathermap.org/data/2.5/weather?q=naze,jp&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #64: yaransk, ru
# http://api.openweathermap.org/data/2.5/weather?q=yaransk,ru&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #65: alofi, nu
# http://api.openweathermap.org/data/2.5/weather?q=alofi,nu&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #66: bend, us
# http://api.openweathermap.org/data/2.5/weather?q=bend,us&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #67: campana, ar
# http://api.openweathermap.org/data/2.5/weather?q=campana,ar&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #68: tsihombe, mg
# http://api.openweathermap.org/data/2.5/weather?q=tsihombe,mg&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Error with city data... Skipping
# Now retrieving City #69: busselton, au
# http://api.openweathermap.org/data/2.5/weather?q=busselton,au&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #70: yellowknife, ca
# http://api.openweathermap.org/data/2.5/weather?q=yellowknife,ca&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #71: saint george, bm
# http://api.openweathermap.org/data/2.5/weather?q=saint george,bm&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #72: nikolskoye, ru
# http://api.openweathermap.org/data/2.5/weather?q=nikolskoye,ru&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #73: saskylakh, ru
# http://api.openweathermap.org/data/2.5/weather?q=saskylakh,ru&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #74: tubruq, ly
# http://api.openweathermap.org/data/2.5/weather?q=tubruq,ly&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Error with city data... Skipping
# Now retrieving City #75: alekseyevsk, ru
# http://api.openweathermap.org/data/2.5/weather?q=alekseyevsk,ru&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #76: narsaq, gl
# http://api.openweathermap.org/data/2.5/weather?q=narsaq,gl&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #77: carmo do paranaiba, br
# http://api.openweathermap.org/data/2.5/weather?q=carmo do paranaiba,br&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #78: tiznit, ma
# http://api.openweathermap.org/data/2.5/weather?q=tiznit,ma&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #79: goderich, sl
# http://api.openweathermap.org/data/2.5/weather?q=goderich,sl&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Error with city data... Skipping
# Now retrieving City #80: floro, no
# http://api.openweathermap.org/data/2.5/weather?q=floro,no&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #81: new norfolk, au
# http://api.openweathermap.org/data/2.5/weather?q=new norfolk,au&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #82: carnarvon, au
# http://api.openweathermap.org/data/2.5/weather?q=carnarvon,au&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #83: beringovskiy, ru
# http://api.openweathermap.org/data/2.5/weather?q=beringovskiy,ru&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #84: qandala, so
# http://api.openweathermap.org/data/2.5/weather?q=qandala,so&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #85: tunkas, mx
# http://api.openweathermap.org/data/2.5/weather?q=tunkas,mx&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #86: vanimo, pg
# http://api.openweathermap.org/data/2.5/weather?q=vanimo,pg&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #87: puerto ayora, ec
# http://api.openweathermap.org/data/2.5/weather?q=puerto ayora,ec&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #88: pisco, pe
# http://api.openweathermap.org/data/2.5/weather?q=pisco,pe&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #89: pulandian, cn
# http://api.openweathermap.org/data/2.5/weather?q=pulandian,cn&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #90: chokurdakh, ru
# http://api.openweathermap.org/data/2.5/weather?q=chokurdakh,ru&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #91: evensk, ru
# http://api.openweathermap.org/data/2.5/weather?q=evensk,ru&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #92: kaitangata, nz
# http://api.openweathermap.org/data/2.5/weather?q=kaitangata,nz&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #93: fairbanks, us
# http://api.openweathermap.org/data/2.5/weather?q=fairbanks,us&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #94: yaan, cn
# http://api.openweathermap.org/data/2.5/weather?q=yaan,cn&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Error with city data... Skipping
# Now retrieving City #95: lagoa, pt
# http://api.openweathermap.org/data/2.5/weather?q=lagoa,pt&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #96: avarua, ck
# http://api.openweathermap.org/data/2.5/weather?q=avarua,ck&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #97: mantua, cu
# http://api.openweathermap.org/data/2.5/weather?q=mantua,cu&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #98: osoyoos, ca
# http://api.openweathermap.org/data/2.5/weather?q=osoyoos,ca&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #99: nizhneyansk, ru
# http://api.openweathermap.org/data/2.5/weather?q=nizhneyansk,ru&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Error with city data... Skipping
# Now retrieving City #100: uwayl, sd
# http://api.openweathermap.org/data/2.5/weather?q=uwayl,sd&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Error with city data... Skipping
# Now retrieving City #101: havre-saint-pierre, ca
# http://api.openweathermap.org/data/2.5/weather?q=havre-saint-pierre,ca&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #102: det udom, th
# http://api.openweathermap.org/data/2.5/weather?q=det udom,th&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #103: airai, pw
# http://api.openweathermap.org/data/2.5/weather?q=airai,pw&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Error with city data... Skipping
# Now retrieving City #104: caravelas, br
# http://api.openweathermap.org/data/2.5/weather?q=caravelas,br&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #105: thompson, ca
# http://api.openweathermap.org/data/2.5/weather?q=thompson,ca&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #106: vila franca do campo, pt
# http://api.openweathermap.org/data/2.5/weather?q=vila franca do campo,pt&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #107: khasan, ru
# http://api.openweathermap.org/data/2.5/weather?q=khasan,ru&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #108: dustlik, uz
# http://api.openweathermap.org/data/2.5/weather?q=dustlik,uz&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #109: tuktoyaktuk, ca
# http://api.openweathermap.org/data/2.5/weather?q=tuktoyaktuk,ca&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #110: faanui, pf
# http://api.openweathermap.org/data/2.5/weather?q=faanui,pf&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #111: pahrump, us
# http://api.openweathermap.org/data/2.5/weather?q=pahrump,us&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #112: brae, gb
# http://api.openweathermap.org/data/2.5/weather?q=brae,gb&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #113: mys shmidta, ru
# http://api.openweathermap.org/data/2.5/weather?q=mys shmidta,ru&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Error with city data... Skipping
# Now retrieving City #114: qitaihe, cn
# http://api.openweathermap.org/data/2.5/weather?q=qitaihe,cn&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #115: belaya gora, ru
# http://api.openweathermap.org/data/2.5/weather?q=belaya gora,ru&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #116: aklavik, ca
# http://api.openweathermap.org/data/2.5/weather?q=aklavik,ca&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #117: hervey bay, au
# http://api.openweathermap.org/data/2.5/weather?q=hervey bay,au&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #118: kodiak, us
# http://api.openweathermap.org/data/2.5/weather?q=kodiak,us&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #119: tokonou, gn
# http://api.openweathermap.org/data/2.5/weather?q=tokonou,gn&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #120: vardo, no
# http://api.openweathermap.org/data/2.5/weather?q=vardo,no&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #121: taolanaro, mg
# http://api.openweathermap.org/data/2.5/weather?q=taolanaro,mg&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Error with city data... Skipping
# Now retrieving City #122: arraial do cabo, br
# http://api.openweathermap.org/data/2.5/weather?q=arraial do cabo,br&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #123: eidsvag, no
# http://api.openweathermap.org/data/2.5/weather?q=eidsvag,no&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #124: high level, ca
# http://api.openweathermap.org/data/2.5/weather?q=high level,ca&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #125: lucapa, ao
# http://api.openweathermap.org/data/2.5/weather?q=lucapa,ao&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #126: flin flon, ca
# http://api.openweathermap.org/data/2.5/weather?q=flin flon,ca&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #127: bubaque, gw
# http://api.openweathermap.org/data/2.5/weather?q=bubaque,gw&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #128: skala fourkas, gr
# http://api.openweathermap.org/data/2.5/weather?q=skala fourkas,gr&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #129: barmer, in
# http://api.openweathermap.org/data/2.5/weather?q=barmer,in&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #130: marsh harbour, bs
# http://api.openweathermap.org/data/2.5/weather?q=marsh harbour,bs&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #131: damghan, ir
# http://api.openweathermap.org/data/2.5/weather?q=damghan,ir&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #132: barentsburg, sj
# http://api.openweathermap.org/data/2.5/weather?q=barentsburg,sj&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Error with city data... Skipping
# Now retrieving City #133: namibe, ao
# http://api.openweathermap.org/data/2.5/weather?q=namibe,ao&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #134: klaksvik, fo
# http://api.openweathermap.org/data/2.5/weather?q=klaksvik,fo&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #135: dok kham tai, th
# http://api.openweathermap.org/data/2.5/weather?q=dok kham tai,th&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #136: comodoro rivadavia, ar
# http://api.openweathermap.org/data/2.5/weather?q=comodoro rivadavia,ar&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #137: senneterre, ca
# http://api.openweathermap.org/data/2.5/weather?q=senneterre,ca&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #138: tasiilaq, gl
# http://api.openweathermap.org/data/2.5/weather?q=tasiilaq,gl&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #139: sentyabrskiy, ru
# http://api.openweathermap.org/data/2.5/weather?q=sentyabrskiy,ru&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Error with city data... Skipping
# Now retrieving City #140: amancio, cu
# http://api.openweathermap.org/data/2.5/weather?q=amancio,cu&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Error with city data... Skipping
# Now retrieving City #141: puerto escondido, mx
# http://api.openweathermap.org/data/2.5/weather?q=puerto escondido,mx&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #142: zarate, ar
# http://api.openweathermap.org/data/2.5/weather?q=zarate,ar&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #143: tanout, ne
# http://api.openweathermap.org/data/2.5/weather?q=tanout,ne&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #144: butterworth, za
# http://api.openweathermap.org/data/2.5/weather?q=butterworth,za&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #145: upernavik, gl
# http://api.openweathermap.org/data/2.5/weather?q=upernavik,gl&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #146: skalistyy, ru
# http://api.openweathermap.org/data/2.5/weather?q=skalistyy,ru&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Error with city data... Skipping
# Now retrieving City #147: ponta do sol, cv
# http://api.openweathermap.org/data/2.5/weather?q=ponta do sol,cv&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #148: victoria, sc
# http://api.openweathermap.org/data/2.5/weather?q=victoria,sc&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #149: bertoua, cm
# http://api.openweathermap.org/data/2.5/weather?q=bertoua,cm&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #150: raudeberg, no
# http://api.openweathermap.org/data/2.5/weather?q=raudeberg,no&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #151: marcona, pe
# http://api.openweathermap.org/data/2.5/weather?q=marcona,pe&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Error with city data... Skipping
# Now retrieving City #152: isangel, vu
# http://api.openweathermap.org/data/2.5/weather?q=isangel,vu&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #153: cheremukhovo, ru
# http://api.openweathermap.org/data/2.5/weather?q=cheremukhovo,ru&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #154: nelson bay, au
# http://api.openweathermap.org/data/2.5/weather?q=nelson bay,au&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #155: gondar, et
# http://api.openweathermap.org/data/2.5/weather?q=gondar,et&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Error with city data... Skipping
# Now retrieving City #156: bilma, ne
# http://api.openweathermap.org/data/2.5/weather?q=bilma,ne&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #157: tadine, nc
# http://api.openweathermap.org/data/2.5/weather?q=tadine,nc&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #158: fortuna, us
# http://api.openweathermap.org/data/2.5/weather?q=fortuna,us&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #159: grand river south east, mu
# http://api.openweathermap.org/data/2.5/weather?q=grand river south east,mu&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Error with city data... Skipping
# Now retrieving City #160: kloulklubed, pw
# http://api.openweathermap.org/data/2.5/weather?q=kloulklubed,pw&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #161: tungkang, tw
# http://api.openweathermap.org/data/2.5/weather?q=tungkang,tw&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Error with city data... Skipping
# Now retrieving City #162: kieta, pg
# http://api.openweathermap.org/data/2.5/weather?q=kieta,pg&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #163: shurugwi, zw
# http://api.openweathermap.org/data/2.5/weather?q=shurugwi,zw&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #164: karratha, au
# http://api.openweathermap.org/data/2.5/weather?q=karratha,au&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #165: halalo, wf
# http://api.openweathermap.org/data/2.5/weather?q=halalo,wf&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Error with city data... Skipping
# Now retrieving City #166: urucara, br
# http://api.openweathermap.org/data/2.5/weather?q=urucara,br&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #167: rawson, ar
# http://api.openweathermap.org/data/2.5/weather?q=rawson,ar&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #168: eydhafushi, mv
# http://api.openweathermap.org/data/2.5/weather?q=eydhafushi,mv&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #169: santa maria del tule, mx
# http://api.openweathermap.org/data/2.5/weather?q=santa maria del tule,mx&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #170: hofn, is
# http://api.openweathermap.org/data/2.5/weather?q=hofn,is&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #171: conde, br
# http://api.openweathermap.org/data/2.5/weather?q=conde,br&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #172: am timan, td
# http://api.openweathermap.org/data/2.5/weather?q=am timan,td&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #173: nome, us
# http://api.openweathermap.org/data/2.5/weather?q=nome,us&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #174: baiyin, cn
# http://api.openweathermap.org/data/2.5/weather?q=baiyin,cn&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #175: kruisfontein, za
# http://api.openweathermap.org/data/2.5/weather?q=kruisfontein,za&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #176: lebu, cl
# http://api.openweathermap.org/data/2.5/weather?q=lebu,cl&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #177: la ronge, ca
# http://api.openweathermap.org/data/2.5/weather?q=la ronge,ca&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #178: grande-riviere, ca
# http://api.openweathermap.org/data/2.5/weather?q=grande-riviere,ca&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Error with city data... Skipping
# Now retrieving City #179: acapulco, mx
# http://api.openweathermap.org/data/2.5/weather?q=acapulco,mx&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #180: roald, no
# http://api.openweathermap.org/data/2.5/weather?q=roald,no&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #181: saint-augustin, ca
# http://api.openweathermap.org/data/2.5/weather?q=saint-augustin,ca&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #182: marrakesh, ma
# http://api.openweathermap.org/data/2.5/weather?q=marrakesh,ma&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #183: buzdyak, ru
# http://api.openweathermap.org/data/2.5/weather?q=buzdyak,ru&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #184: kudahuvadhoo, mv
# http://api.openweathermap.org/data/2.5/weather?q=kudahuvadhoo,mv&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #185: praia, cv
# http://api.openweathermap.org/data/2.5/weather?q=praia,cv&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #186: longyearbyen, sj
# http://api.openweathermap.org/data/2.5/weather?q=longyearbyen,sj&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #187: bathsheba, bb
# http://api.openweathermap.org/data/2.5/weather?q=bathsheba,bb&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #188: belyy yar, ru
# http://api.openweathermap.org/data/2.5/weather?q=belyy yar,ru&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #189: manokwari, id
# http://api.openweathermap.org/data/2.5/weather?q=manokwari,id&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #190: guerrero negro, mx
# http://api.openweathermap.org/data/2.5/weather?q=guerrero negro,mx&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #191: altay, cn
# http://api.openweathermap.org/data/2.5/weather?q=altay,cn&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #192: alamor, ec
# http://api.openweathermap.org/data/2.5/weather?q=alamor,ec&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #193: souillac, mu
# http://api.openweathermap.org/data/2.5/weather?q=souillac,mu&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #194: drayton valley, ca
# http://api.openweathermap.org/data/2.5/weather?q=drayton valley,ca&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #195: bunia, cd
# http://api.openweathermap.org/data/2.5/weather?q=bunia,cd&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #196: yabelo, et
# http://api.openweathermap.org/data/2.5/weather?q=yabelo,et&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #197: port hedland, au
# http://api.openweathermap.org/data/2.5/weather?q=port hedland,au&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #198: sassandra, ci
# http://api.openweathermap.org/data/2.5/weather?q=sassandra,ci&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #199: georgetown, sh
# http://api.openweathermap.org/data/2.5/weather?q=georgetown,sh&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #200: karasburg, na
# http://api.openweathermap.org/data/2.5/weather?q=karasburg,na&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #201: vaitupu, wf
# http://api.openweathermap.org/data/2.5/weather?q=vaitupu,wf&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Error with city data... Skipping
# Now retrieving City #202: tan an, vn
# http://api.openweathermap.org/data/2.5/weather?q=tan an,vn&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #203: asau, tv
# http://api.openweathermap.org/data/2.5/weather?q=asau,tv&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Error with city data... Skipping
# Now retrieving City #204: takoradi, gh
# http://api.openweathermap.org/data/2.5/weather?q=takoradi,gh&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #205: luderitz, na
# http://api.openweathermap.org/data/2.5/weather?q=luderitz,na&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #206: moroni, km
# http://api.openweathermap.org/data/2.5/weather?q=moroni,km&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #207: qasigiannguit, gl
# http://api.openweathermap.org/data/2.5/weather?q=qasigiannguit,gl&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #208: tabory, ru
# http://api.openweathermap.org/data/2.5/weather?q=tabory,ru&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #209: shimoda, jp
# http://api.openweathermap.org/data/2.5/weather?q=shimoda,jp&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #210: nata, bw
# http://api.openweathermap.org/data/2.5/weather?q=nata,bw&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #211: hovd, mn
# http://api.openweathermap.org/data/2.5/weather?q=hovd,mn&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #212: eldorado, ar
# http://api.openweathermap.org/data/2.5/weather?q=eldorado,ar&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #213: bayeux, fr
# http://api.openweathermap.org/data/2.5/weather?q=bayeux,fr&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #214: batagay-alyta, ru
# http://api.openweathermap.org/data/2.5/weather?q=batagay-alyta,ru&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #215: khatanga, ru
# http://api.openweathermap.org/data/2.5/weather?q=khatanga,ru&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #216: zinder, ne
# http://api.openweathermap.org/data/2.5/weather?q=zinder,ne&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #217: ojinaga, mx
# http://api.openweathermap.org/data/2.5/weather?q=ojinaga,mx&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #218: maputo, mz
# http://api.openweathermap.org/data/2.5/weather?q=maputo,mz&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #219: salinas, ec
# http://api.openweathermap.org/data/2.5/weather?q=salinas,ec&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #220: attawapiskat, ca
# http://api.openweathermap.org/data/2.5/weather?q=attawapiskat,ca&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Error with city data... Skipping
# Now retrieving City #221: deputatskiy, ru
# http://api.openweathermap.org/data/2.5/weather?q=deputatskiy,ru&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #222: los llanos de aridane, es
# http://api.openweathermap.org/data/2.5/weather?q=los llanos de aridane,es&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #223: lakes entrance, au
# http://api.openweathermap.org/data/2.5/weather?q=lakes entrance,au&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #224: ikom, ng
# http://api.openweathermap.org/data/2.5/weather?q=ikom,ng&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #225: nizwa, om
# http://api.openweathermap.org/data/2.5/weather?q=nizwa,om&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #226: ratnagiri, in
# http://api.openweathermap.org/data/2.5/weather?q=ratnagiri,in&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #227: wahran, dz
# http://api.openweathermap.org/data/2.5/weather?q=wahran,dz&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Error with city data... Skipping
# Now retrieving City #228: zabolotovka, ru
# http://api.openweathermap.org/data/2.5/weather?q=zabolotovka,ru&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #229: petropavlovskoye, ru
# http://api.openweathermap.org/data/2.5/weather?q=petropavlovskoye,ru&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #230: sorvag, fo
# http://api.openweathermap.org/data/2.5/weather?q=sorvag,fo&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Error with city data... Skipping
# Now retrieving City #231: esperance, au
# http://api.openweathermap.org/data/2.5/weather?q=esperance,au&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #232: ambon, id
# http://api.openweathermap.org/data/2.5/weather?q=ambon,id&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #233: kuybyshevo, ru
# http://api.openweathermap.org/data/2.5/weather?q=kuybyshevo,ru&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #234: cavalcante, br
# http://api.openweathermap.org/data/2.5/weather?q=cavalcante,br&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #235: bom jesus da lapa, br
# http://api.openweathermap.org/data/2.5/weather?q=bom jesus da lapa,br&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #236: samusu, ws
# http://api.openweathermap.org/data/2.5/weather?q=samusu,ws&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Error with city data... Skipping
# Now retrieving City #237: oudtshoorn, za
# http://api.openweathermap.org/data/2.5/weather?q=oudtshoorn,za&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #238: sinnamary, gf
# http://api.openweathermap.org/data/2.5/weather?q=sinnamary,gf&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #239: viransehir, tr
# http://api.openweathermap.org/data/2.5/weather?q=viransehir,tr&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #240: tigil, ru
# http://api.openweathermap.org/data/2.5/weather?q=tigil,ru&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #241: alghero, it
# http://api.openweathermap.org/data/2.5/weather?q=alghero,it&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #242: koszalin, pl
# http://api.openweathermap.org/data/2.5/weather?q=koszalin,pl&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #243: ngukurr, au
# http://api.openweathermap.org/data/2.5/weather?q=ngukurr,au&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Error with city data... Skipping
# Now retrieving City #244: tessalit, ml
# http://api.openweathermap.org/data/2.5/weather?q=tessalit,ml&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #245: adrar, dz
# http://api.openweathermap.org/data/2.5/weather?q=adrar,dz&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #246: leon, ni
# http://api.openweathermap.org/data/2.5/weather?q=leon,ni&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #247: coquimbo, cl
# http://api.openweathermap.org/data/2.5/weather?q=coquimbo,cl&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #248: belushya guba, ru
# http://api.openweathermap.org/data/2.5/weather?q=belushya guba,ru&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Error with city data... Skipping
# Now retrieving City #249: bambanglipuro, id
# http://api.openweathermap.org/data/2.5/weather?q=bambanglipuro,id&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #250: bac lieu, vn
# http://api.openweathermap.org/data/2.5/weather?q=bac lieu,vn&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Error with city data... Skipping
# Now retrieving City #251: indramayu, id
# http://api.openweathermap.org/data/2.5/weather?q=indramayu,id&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #252: ashqelon, il
# http://api.openweathermap.org/data/2.5/weather?q=ashqelon,il&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #253: puerto colombia, co
# http://api.openweathermap.org/data/2.5/weather?q=puerto colombia,co&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #254: nautla, mx
# http://api.openweathermap.org/data/2.5/weather?q=nautla,mx&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #255: goure, ne
# http://api.openweathermap.org/data/2.5/weather?q=goure,ne&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #256: port arthur, us
# http://api.openweathermap.org/data/2.5/weather?q=port arthur,us&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #257: labuhan, id
# http://api.openweathermap.org/data/2.5/weather?q=labuhan,id&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #258: pevek, ru
# http://api.openweathermap.org/data/2.5/weather?q=pevek,ru&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #259: waipawa, nz
# http://api.openweathermap.org/data/2.5/weather?q=waipawa,nz&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #260: tumkur, in
# http://api.openweathermap.org/data/2.5/weather?q=tumkur,in&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #261: ancud, cl
# http://api.openweathermap.org/data/2.5/weather?q=ancud,cl&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #262: ayr, au
# http://api.openweathermap.org/data/2.5/weather?q=ayr,au&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #263: san patricio, mx
# http://api.openweathermap.org/data/2.5/weather?q=san patricio,mx&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #264: yerbogachen, ru
# http://api.openweathermap.org/data/2.5/weather?q=yerbogachen,ru&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #265: itoman, jp
# http://api.openweathermap.org/data/2.5/weather?q=itoman,jp&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #266: sobradinho, br
# http://api.openweathermap.org/data/2.5/weather?q=sobradinho,br&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #267: cuamba, mz
# http://api.openweathermap.org/data/2.5/weather?q=cuamba,mz&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #268: rocklin, us
# http://api.openweathermap.org/data/2.5/weather?q=rocklin,us&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #269: te anau, nz
# http://api.openweathermap.org/data/2.5/weather?q=te anau,nz&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #270: sisimiut, gl
# http://api.openweathermap.org/data/2.5/weather?q=sisimiut,gl&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #271: olga, ru
# http://api.openweathermap.org/data/2.5/weather?q=olga,ru&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #272: kyren, ru
# http://api.openweathermap.org/data/2.5/weather?q=kyren,ru&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #273: meyungs, pw
# http://api.openweathermap.org/data/2.5/weather?q=meyungs,pw&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Error with city data... Skipping
# Now retrieving City #274: virginia beach, us
# http://api.openweathermap.org/data/2.5/weather?q=virginia beach,us&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #275: bontang, id
# http://api.openweathermap.org/data/2.5/weather?q=bontang,id&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #276: bethel, us
# http://api.openweathermap.org/data/2.5/weather?q=bethel,us&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #277: bilibino, ru
# http://api.openweathermap.org/data/2.5/weather?q=bilibino,ru&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #278: amderma, ru
# http://api.openweathermap.org/data/2.5/weather?q=amderma,ru&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Error with city data... Skipping
# Now retrieving City #279: ribeira grande, pt
# http://api.openweathermap.org/data/2.5/weather?q=ribeira grande,pt&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #280: turayf, sa
# http://api.openweathermap.org/data/2.5/weather?q=turayf,sa&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #281: ixtapa, mx
# http://api.openweathermap.org/data/2.5/weather?q=ixtapa,mx&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #282: kavaratti, in
# http://api.openweathermap.org/data/2.5/weather?q=kavaratti,in&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #283: muncar, id
# http://api.openweathermap.org/data/2.5/weather?q=muncar,id&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #284: benalla, au
# http://api.openweathermap.org/data/2.5/weather?q=benalla,au&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #285: palmer, us
# http://api.openweathermap.org/data/2.5/weather?q=palmer,us&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #286: rio grande, br
# http://api.openweathermap.org/data/2.5/weather?q=rio grande,br&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #287: hostotipaquillo, mx
# http://api.openweathermap.org/data/2.5/weather?q=hostotipaquillo,mx&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #288: constitucion, mx
# http://api.openweathermap.org/data/2.5/weather?q=constitucion,mx&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #289: mildura, au
# http://api.openweathermap.org/data/2.5/weather?q=mildura,au&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #290: yarmouth, ca
# http://api.openweathermap.org/data/2.5/weather?q=yarmouth,ca&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #291: el alto, pe
# http://api.openweathermap.org/data/2.5/weather?q=el alto,pe&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Error with city data... Skipping
# Now retrieving City #292: katherine, au
# http://api.openweathermap.org/data/2.5/weather?q=katherine,au&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #293: lata, sb
# http://api.openweathermap.org/data/2.5/weather?q=lata,sb&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Error with city data... Skipping
# Now retrieving City #294: greytown, za
# http://api.openweathermap.org/data/2.5/weather?q=greytown,za&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #295: pula, hr
# http://api.openweathermap.org/data/2.5/weather?q=pula,hr&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# ...
# Now retrieving City #527: abha, sa
# http://api.openweathermap.org/data/2.5/weather?q=abha,sa&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #528: bantry, ie
# http://api.openweathermap.org/data/2.5/weather?q=bantry,ie&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #529: honiara, sb
# http://api.openweathermap.org/data/2.5/weather?q=honiara,sb&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #530: norman wells, ca
# http://api.openweathermap.org/data/2.5/weather?q=norman wells,ca&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #531: yirol, sd
# http://api.openweathermap.org/data/2.5/weather?q=yirol,sd&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Error with city data... Skipping
# Now retrieving City #532: haibowan, cn
# http://api.openweathermap.org/data/2.5/weather?q=haibowan,cn&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Error with city data... Skipping
# Now retrieving City #533: vilyuysk, ru
# http://api.openweathermap.org/data/2.5/weather?q=vilyuysk,ru&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #534: quatre cocos, mu
# http://api.openweathermap.org/data/2.5/weather?q=quatre cocos,mu&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #535: pacifica, us
# http://api.openweathermap.org/data/2.5/weather?q=pacifica,us&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #536: palana, ru
# http://api.openweathermap.org/data/2.5/weather?q=palana,ru&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #537: west wendover, us
# http://api.openweathermap.org/data/2.5/weather?q=west wendover,us&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #538: kisangani, cd
# http://api.openweathermap.org/data/2.5/weather?q=kisangani,cd&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #539: rheden, nl
# http://api.openweathermap.org/data/2.5/weather?q=rheden,nl&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #540: trairi, br
# http://api.openweathermap.org/data/2.5/weather?q=trairi,br&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #541: uyuni, bo
# http://api.openweathermap.org/data/2.5/weather?q=uyuni,bo&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #542: kungurtug, ru
# http://api.openweathermap.org/data/2.5/weather?q=kungurtug,ru&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #543: vrede, za
# http://api.openweathermap.org/data/2.5/weather?q=vrede,za&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #544: rock sound, bs
# http://api.openweathermap.org/data/2.5/weather?q=rock sound,bs&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #545: rudnichnyy, ru
# http://api.openweathermap.org/data/2.5/weather?q=rudnichnyy,ru&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #546: keti bandar, pk
# http://api.openweathermap.org/data/2.5/weather?q=keti bandar,pk&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #547: port augusta, au
# http://api.openweathermap.org/data/2.5/weather?q=port augusta,au&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #548: yuzhno-yeniseyskiy, ru
# http://api.openweathermap.org/data/2.5/weather?q=yuzhno-yeniseyskiy,ru&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Error with city data... Skipping
# Now retrieving City #549: bowen, au
# http://api.openweathermap.org/data/2.5/weather?q=bowen,au&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #550: tari, pg
# http://api.openweathermap.org/data/2.5/weather?q=tari,pg&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Error with city data... Skipping
# Now retrieving City #551: gazni, af
# http://api.openweathermap.org/data/2.5/weather?q=gazni,af&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Error with city data... Skipping
# Now retrieving City #552: funadhoo, mv
# http://api.openweathermap.org/data/2.5/weather?q=funadhoo,mv&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #553: ambulu, id
# http://api.openweathermap.org/data/2.5/weather?q=ambulu,id&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #554: oriximina, br
# http://api.openweathermap.org/data/2.5/weather?q=oriximina,br&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #555: cascais, pt
# http://api.openweathermap.org/data/2.5/weather?q=cascais,pt&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #556: sungaipenuh, id
# http://api.openweathermap.org/data/2.5/weather?q=sungaipenuh,id&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #557: tacuarembo, uy
# http://api.openweathermap.org/data/2.5/weather?q=tacuarembo,uy&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #558: barbastro, es
# http://api.openweathermap.org/data/2.5/weather?q=barbastro,es&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #559: tandil, ar
# http://api.openweathermap.org/data/2.5/weather?q=tandil,ar&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #560: ilulissat, gl
# http://api.openweathermap.org/data/2.5/weather?q=ilulissat,gl&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #561: tiksi, ru
# http://api.openweathermap.org/data/2.5/weather?q=tiksi,ru&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #562: dicabisagan, ph
# http://api.openweathermap.org/data/2.5/weather?q=dicabisagan,ph&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #563: egvekinot, ru
# http://api.openweathermap.org/data/2.5/weather?q=egvekinot,ru&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #564: olafsvik, is
# http://api.openweathermap.org/data/2.5/weather?q=olafsvik,is&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Error with city data... Skipping
# Now retrieving City #565: kirov, ru
# http://api.openweathermap.org/data/2.5/weather?q=kirov,ru&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #566: port blair, in
# http://api.openweathermap.org/data/2.5/weather?q=port blair,in&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #567: chagda, ru
# http://api.openweathermap.org/data/2.5/weather?q=chagda,ru&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Error with city data... Skipping
# Now retrieving City #568: rock springs, us
# http://api.openweathermap.org/data/2.5/weather?q=rock springs,us&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #569: davila, ph
# http://api.openweathermap.org/data/2.5/weather?q=davila,ph&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #570: iwanai, jp
# http://api.openweathermap.org/data/2.5/weather?q=iwanai,jp&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #571: hami, cn
# http://api.openweathermap.org/data/2.5/weather?q=hami,cn&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #572: alto araguaia, br
# http://api.openweathermap.org/data/2.5/weather?q=alto araguaia,br&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #573: merrill, us
# http://api.openweathermap.org/data/2.5/weather?q=merrill,us&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #574: garowe, so
# http://api.openweathermap.org/data/2.5/weather?q=garowe,so&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #575: bisceglie, it
# http://api.openweathermap.org/data/2.5/weather?q=bisceglie,it&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #576: ust-barguzin, ru
# http://api.openweathermap.org/data/2.5/weather?q=ust-barguzin,ru&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #577: taltal, cl
# http://api.openweathermap.org/data/2.5/weather?q=taltal,cl&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #578: guiren, cn
# http://api.openweathermap.org/data/2.5/weather?q=guiren,cn&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #579: tateyama, jp
# http://api.openweathermap.org/data/2.5/weather?q=tateyama,jp&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #580: hirara, jp
# http://api.openweathermap.org/data/2.5/weather?q=hirara,jp&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #581: ginir, et
# http://api.openweathermap.org/data/2.5/weather?q=ginir,et&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #582: gander, ca
# http://api.openweathermap.org/data/2.5/weather?q=gander,ca&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #583: westport, ie
# http://api.openweathermap.org/data/2.5/weather?q=westport,ie&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #584: burnie, au
# http://api.openweathermap.org/data/2.5/weather?q=burnie,au&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #585: chone, ec
# http://api.openweathermap.org/data/2.5/weather?q=chone,ec&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #586: bonavista, ca
# http://api.openweathermap.org/data/2.5/weather?q=bonavista,ca&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #587: graaff-reinet, za
# http://api.openweathermap.org/data/2.5/weather?q=graaff-reinet,za&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #588: sibolga, id
# http://api.openweathermap.org/data/2.5/weather?q=sibolga,id&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #589: bukama, cd
# http://api.openweathermap.org/data/2.5/weather?q=bukama,cd&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #590: palabuhanratu, id
# http://api.openweathermap.org/data/2.5/weather?q=palabuhanratu,id&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Error with city data... Skipping
# Now retrieving City #591: suntar, ru
# http://api.openweathermap.org/data/2.5/weather?q=suntar,ru&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #592: minusio, ch
# http://api.openweathermap.org/data/2.5/weather?q=minusio,ch&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #593: asht, tj
# http://api.openweathermap.org/data/2.5/weather?q=asht,tj&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Error with city data... Skipping
# Now retrieving City #594: zaranj, af
# http://api.openweathermap.org/data/2.5/weather?q=zaranj,af&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #595: malwan, in
# http://api.openweathermap.org/data/2.5/weather?q=malwan,in&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Error with city data... Skipping
# Now retrieving City #596: ulladulla, au
# http://api.openweathermap.org/data/2.5/weather?q=ulladulla,au&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #597: mahmudabad, in
# http://api.openweathermap.org/data/2.5/weather?q=mahmudabad,in&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #598: imbituba, br
# http://api.openweathermap.org/data/2.5/weather?q=imbituba,br&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #599: basco, ph
# http://api.openweathermap.org/data/2.5/weather?q=basco,ph&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #600: jutai, br
# http://api.openweathermap.org/data/2.5/weather?q=jutai,br&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #601: coihaique, cl
# http://api.openweathermap.org/data/2.5/weather?q=coihaique,cl&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #602: yumen, cn
# http://api.openweathermap.org/data/2.5/weather?q=yumen,cn&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #603: bahia blanca, ar
# http://api.openweathermap.org/data/2.5/weather?q=bahia blanca,ar&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #604: christchurch, nz
# http://api.openweathermap.org/data/2.5/weather?q=christchurch,nz&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #605: quballat, tn
# http://api.openweathermap.org/data/2.5/weather?q=quballat,tn&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #606: riverton, us
# http://api.openweathermap.org/data/2.5/weather?q=riverton,us&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #607: cody, us
# http://api.openweathermap.org/data/2.5/weather?q=cody,us&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #608: mujiayingzi, cn
# http://api.openweathermap.org/data/2.5/weather?q=mujiayingzi,cn&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #609: enshi, cn
# http://api.openweathermap.org/data/2.5/weather?q=enshi,cn&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #610: bijar, ir
# http://api.openweathermap.org/data/2.5/weather?q=bijar,ir&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #611: maine-soroa, ne
# http://api.openweathermap.org/data/2.5/weather?q=maine-soroa,ne&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #612: taoudenni, ml
# http://api.openweathermap.org/data/2.5/weather?q=taoudenni,ml&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #613: bull savanna, jm
# http://api.openweathermap.org/data/2.5/weather?q=bull savanna,jm&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #614: qaqortoq, gl
# http://api.openweathermap.org/data/2.5/weather?q=qaqortoq,gl&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #615: wajir, ke
# http://api.openweathermap.org/data/2.5/weather?q=wajir,ke&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #616: saldanha, za
# http://api.openweathermap.org/data/2.5/weather?q=saldanha,za&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #617: ribeira brava, cv
# http://api.openweathermap.org/data/2.5/weather?q=ribeira brava,cv&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Error with city data... Skipping
# Now retrieving City #618: ranfurly, nz
# http://api.openweathermap.org/data/2.5/weather?q=ranfurly,nz&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #619: grand centre, ca
# http://api.openweathermap.org/data/2.5/weather?q=grand centre,ca&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Error with city data... Skipping
# Now retrieving City #620: kinanah, sd
# http://api.openweathermap.org/data/2.5/weather?q=kinanah,sd&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Error with city data... Skipping
# Now retrieving City #621: haines junction, ca
# http://api.openweathermap.org/data/2.5/weather?q=haines junction,ca&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #622: merauke, id
# http://api.openweathermap.org/data/2.5/weather?q=merauke,id&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #623: menongue, ao
# http://api.openweathermap.org/data/2.5/weather?q=menongue,ao&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #624: gao, ml
# http://api.openweathermap.org/data/2.5/weather?q=gao,ml&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #625: matara, lk
# http://api.openweathermap.org/data/2.5/weather?q=matara,lk&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# Now retrieving City #626: chalons-en-champagne, fr
# http://api.openweathermap.org/data/2.5/weather?q=chalons-en-champagne,fr&units=imperial&appid=bec2deb1e63f486b3e900db56c9f377f
# ---------------------------------------------------------------
# Data Retrieval Complete
# ---------------------------------------------------------------

# %%
#Drop NaN values from DataFrame
cities_df.dropna(inplace=True)

#Display final DataFrame
cities_df.head()
# Out:
#           City Country  Latitude  Longitude  Temperature (F)  Humidity (%)  \
# 0  antofagasta      cl    -23.77     -72.90            66.20          68.0
# 1         hilo      us      2.12    -159.92            78.80          65.0
# 3        kapaa      us     14.44    -176.99            72.41          73.0
# 6          eyl      so      6.48      50.52            77.04         100.0
# 7      qaanaaq      gl     89.13     -81.91            -8.06          77.0
#
#    Cloudiness (%)  Wind Speed (mph)
# 0            75.0             13.87
# 1            20.0              2.28
# 3             1.0              3.36
# 6             0.0             11.90
# 7             0.0              8.77

# %%
#Check for missing values in DataFrame
cities_df.count()
# Out:
# City                545
# Country             545
# Latitude            545
# Longitude           545
# Temperature (F)     545
# Humidity (%)        545
# Cloudiness (%)      545
# Wind Speed (mph)    545
# dtype: int64

# %%
#Export DataFrame as CSV
cities_df.to_csv("Output/city_weather_info.csv")

# %% [markdown]
# ### Latitude vs Temperature Plot

# %%
#Define axis values
x_axis = cities_df["Latitude"]
y_axis = cities_df["Temperature (F)"]

#Set size of scatter plots
plt.figure(figsize=(10,6))

#Create scatter plot
plt.scatter(x_axis, y_axis, color="navy", edgecolors="black")

#Aesthetics
plt.title("City Latitude vs Temperature " + "(" + time.strftime("%m/%d/%Y") + ")", fontsize=20)
plt.xlabel("Latitude", fontsize=14)
plt.xlim(-80,100)
plt.ylabel("Temperature (F)", fontsize=14)
plt.ylim(-100,150)

#Save plot as PNG image
plt.savefig("Images/Latitude_vs_Temperature.png")

plt.grid()
plt.show()

# %% [markdown]
# ### Latitude vs Humidity Plot

# %%
#Define axis values
x_axis = cities_df["Latitude"]
y_axis = cities_df["Humidity (%)"]

#Set size of scatter plots
plt.figure(figsize=(10,6))

#Create scatter plot
plt.scatter(x_axis, y_axis, color="green", edgecolors="black")

#Aesthetics
plt.title("City Latitude vs Humidity " + "(" + time.strftime("%m/%d/%Y") + ")", fontsize=20)
plt.xlabel("Latitude", fontsize=14)
plt.xlim(-80,100)
plt.ylabel("Humidity (%)", fontsize=14)
plt.ylim(-20,125)

#Save plot as PNG image
plt.savefig("Images/Latitude_vs_Humidity.png")

plt.grid()
plt.show()

# %% [markdown]
# ### Latitude vs Cloudiness Plot

# %%
#Define axis values
x_axis = cities_df["Latitude"]
y_axis = cities_df["Cloudiness (%)"]

#Set size of scatter plots
plt.figure(figsize=(10,6))

#Create scatter plot
plt.scatter(x_axis, y_axis, color="blue", edgecolors="black")

#Aesthetics
plt.title("City Latitude vs Cloudiness " + "(" + time.strftime("%m/%d/%Y") + ")", fontsize=20)
plt.xlabel("Latitude", fontsize=14)
plt.xlim(-80,100)
plt.ylabel("Cloudiness (%)", fontsize=14)
plt.ylim(-20,125)

#Save plot as PNG image
plt.savefig("Images/Latitude_vs_Cloudiness.png")

plt.grid()
plt.show()

# %% [markdown]
# ### Latitude vs Wind Speed Plot

# %%
#Define axis values
x_axis = cities_df["Latitude"]
y_axis = cities_df["Wind Speed (mph)"]

#Set size of scatter plots
plt.figure(figsize=(10,6))

#Create scatter plot
plt.scatter(x_axis, y_axis, color="orange", edgecolors="black")

#Aesthetics
plt.title("City Latitude vs Wind Speed " + "(" + time.strftime("%m/%d/%Y") + ")", fontsize=20)
plt.xlabel("Latitude", fontsize=14)
plt.xlim(-80,100)
plt.ylabel("Wind Speed (mph)", fontsize=14)
plt.ylim(-5,40)

#Save plot as PNG image
plt.savefig("Images/Latitude_vs_WindSpeed.png")

plt.grid()
plt.show()
